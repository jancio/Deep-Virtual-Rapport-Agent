# %%
#######################################################################################################################
# Project: Deep Virtual Rapport Agent (head gesture detector)
#
#     Jan Ondras (jo951030@gmail.com)
#     Institute for Creative Technologies, University of Southern California
#     April-October 2019
#
#######################################################################################################################
################################################ Head Gesture Detector ################################################
#######################################################################################################################
#
#     Annotates frames of given csv files of vision features (by OpenFace) with nod, shake, and tilt head gestures, 
#     using the developed Head Gesture Detector.
#
#     Uses the best HGD models from ./checkpoints/final_4comb/best/final_4comb_*.hdf5
#     trained on the whole 4comb dataset (training setting TS3) using the script train_final_4comb_hgd.py
#
#     For each input recording (as csv)
#         Resample feature dataframe to 30Hz as used by the Head Gesture Detector
#         Add first derivatives of selected features
#         Annotate frames using the Head Gesture Detector
#         Save as new annotated csv dataframe
#
#     Each output csv file differs from the corresponding input csv file in the following:
#
#         All columns are resampled to 30 FPS
#
#         12 new columns of difference features:
#             Prefix "diff_" denotes first-order differences
#             Prefix "diff2_" denotes second-order differences
#
#         6 new columns of predictions from 3 independent binary head gesture classifiers (nod/shake/tilt):
#             Suffix "_prob" denotes probability of a positive (head gesture occurred) class
#             Binary output 1 denotes a positive (head gesture occurred) class
#                 These binary predictions are smoothed with a median filter with a kernel size of 9 frames (this smoothing may cause that probabilities for some frames are not in agreement with associated binary labels)
#                 Columns with suffix "_NS" denote non-smoothed binary outputs
#
#         4 new columns of fused predictions from the 3 independent binary classifiers, so that only one unique head gesture is predicted at a time:
#             Labels 0/1/2/3 denote none/nod/shake/tilt head gesture classes respectively
#             Columns with suffix "_NS" denote fused predictions of non-smoothed binary outputs (other columns are based on smoothed binary outputs)
#             
#             Columns starting with "head_gesture_max_probab" contain labels fused using the max probability fusion:
#                 If exactly one classifier detects a head gesture, assign this head gesture class      
#                 If multiple classifiers detect a head gesture, assign the highest probability class
#                     Tie resolution: if there are multiple max probabilities, assign none class
#                 Otherwise, assign none class
#
#             Columns starting with "head_gesture_unique" contain labels fused using the unique fusion:
#                 If exactly one classifier detects a head gesture, assign this head gesture class          
#                 Otherwise, assign none class
#######################################################################################################################

# %%
#######################################################################################################################
# So far the Head Gesture Detector (HGD) was run on
# - Mimicry DB (for the main project to develop rapport models)
# - CCDb (to evaluate and compare the performance of the HGD with previous works)
# - IPD data from Qintian Li (summer intern, 2019)
#
# The only changes between different datasets are the DATASET_NAME, paths and the main loop condition
#######################################################################################################################

###########################################################
import numpy as np
random_seed = 37
np.random.seed(random_seed)
from tensorflow import set_random_seed
set_random_seed(random_seed)
###########################################################

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"

from keras.models import Sequential, load_model
from utils import SMOOTHING_KERNEL_SIZE
from collections import defaultdict
import pandas as pd
from keras import backend as K
import glob
import time
# from matplotlib import pyplot as plt
import scipy.signal
from scipy import interpolate

WINDOW_SIZE = 32
MASK_VALUE = 7777777.7777777

# Unified frame rate
FRAME_RATE = 30.

# OpenFace vision features whose first and second derivatives will be calculated
diff_selected_features = [
    ' pose_Tx', 
    ' pose_Ty', 
    ' pose_Tz', 

    ' pose_Rx', 
    ' pose_Ry', 
    ' pose_Rz'    
    # add landmarks?
]

selected_features = [
    'diff_ pose_Tx', 
    'diff_ pose_Ty', 
    'diff_ pose_Tz',
    
    'diff2_ pose_Tx', 
    'diff2_ pose_Ty', 
    'diff2_ pose_Tz',

    'diff_ pose_Rx', 
    'diff_ pose_Ry', 
    'diff_ pose_Rz',
    
    'diff2_ pose_Rx', 
    'diff2_ pose_Ry', 
    'diff2_ pose_Rz',
]

head_gestures = ['nod', 'shake', 'tilt']
model_names = {
    # Models trained on the whole 4comb dataset
    'nod':   'final_4comb_nod_32ws_12f_16u.hdf5', 
    'shake': 'final_4comb_shake_32ws_12f_8u.hdf5', 
    'tilt':  'final_4comb_tilt_32ws_12f_16u.hdf5'
    # Models not trained on the whole 4comb dataset (checpoints are in the folder ./checkpoints/4comb/best)
#     'nod':   '4comb_nod_32ws_12f_16u.hdf5', 
#     'shake': '4comb_shake_32ws_12f_8u.hdf5', 
#     'tilt':  '4comb_tilt_32ws_12f_16u.hdf5'
}

# DATASET_NAME = 'QintianLi_IPD'
# input_features_dir = f'/media/DataDrive/{DATASET_NAME}_openface'
# output_dir = f'/media/DataDrive/{DATASET_NAME}_hgd_annotated_features'

# DATASET_NAME = 'ccdb'
# input_features_dir = f'/home/ICT2000/jondras/dvra_datasets/{DATASET_NAME}/openface_features'
# output_dir = f'/home/ICT2000/jondras/dvra_datasets/{DATASET_NAME}/hgd_annotated_features'

DATASET_NAME = 'mimicry'
input_features_dir = f'/home/ICT2000/jondras/dvra_datasets/{DATASET_NAME}/vision_features/original_openface_features'
output_dir = f'/home/ICT2000/jondras/dvra_datasets/{DATASET_NAME}/vision_features/annotated_features'

models_path_prefix = '/home/ICT2000/jondras/deep-virtual-rapport-agent/head_gesture_detector/checkpoints/final_4comb/best'
# models_path_prefix = '/home/ICT2000/jondras/deep-virtual-rapport-agent/head_gesture_detector/checkpoints/4comb/best'

print(f'Dataset: {DATASET_NAME}')
if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
    
def get_X_segments(df):
    """Generate segments (X (features)) from the dataframe. 

    Args:
        df (DataFrame): Pandas DataFrame that already contains the selected features.

    Returns:
        (3D array): Array of segments/sequences of features.
    """

    X = []

    # Pre-pad all features with (WINDOW_SIZE - 1) MASK_VALUE-s 
    padded_features = np.pad(df.values, ((WINDOW_SIZE - 1, 0), (0, 0)), 
                             mode='constant', constant_values=(MASK_VALUE, MASK_VALUE))
    assert len(padded_features) - WINDOW_SIZE + 1 == len(df), 'Padding failed!'

    # Slide window of length WINDOW_SIZE over the padded features
    for i in range(len(df)):       
        X.append( padded_features[i:i + WINDOW_SIZE] )

    return np.array(X)


def max_probab_fusion(row, smooth_flag):
    """Apply maximum probability fusion to the given row of nod, shake and tilt labels, 
    so that only one unique head gesture is predicted at a time.
    
    If exactly one classifier detects a head gesture, assign this head gesture class.      
    If multiple classifiers detect a head gesture, assign the highest probability class.
        tie resolution: if there are multiple max probabilities, assign none class.
    Otherwise, assign none class.
    
    Args:
        row (dict): DataFrame row with nod, shake and tilt binary labels and probabilities
        smooth_flag (str): Flag indicating whether to use smoothed labels ('') or non-smoothed ('_NS')
    
    Returns:
        (int): Label of the maximum probability label (0/1/2/3 denote none/nod/shake/tilt head 
        gesture classes respectively)
    """
        
    if (row[f'nod{smooth_flag}'] + row[f'shake{smooth_flag}'] + row[f'tilt{smooth_flag}']) > 1:
        max_probab_class = 1 + np.argmax([row['nod_probab'], row['shake_probab'], row['tilt_probab']])
        if max_probab_class == 1:
            if (row['nod_probab'] == row['shake_probab']) or (row['nod_probab'] == row['tilt_probab']):
                print('\t\tTie 1')
                return 0
        elif max_probab_class == 2:
            if (row['shake_probab'] == row['tilt_probab']):
                print('\t\tTie 2')
                return 0
        return max_probab_class
    return np.argmax([0, row[f'nod{smooth_flag}'], row[f'shake{smooth_flag}'], row[f'tilt{smooth_flag}']])
           
def XXX(row, smooth_flag):
    """Apply unique fusion to the given row of nod, shake and tilt labels, 
    so that only one unique head gesture is predicted at a time.
    
    If exactly one classifier detects a head gesture, assign this head gesture class. 
    Otherwise, assign none class.
        
    Args:
        row (dict): DataFrame row with nod, shake and tilt binary labels and probabilities
        smooth_flag (str): Flag indicating whether to use smoothed labels ('') or non-smoothed ('_NS')
    
    Returns:
        (int): Fused label (0/1/2/3 denote none/nod/shake/tilt head gesture classes respectively)
    """
    
    if (row[f'nod{smooth_flag}'] + row[f'shake{smooth_flag}'] + row[f'tilt{smooth_flag}']) == 1:
        return 1 + np.argmax([row[f'nod{smooth_flag}'], row[f'shake{smooth_flag}'], row[f'tilt{smooth_flag}']])
    return 0

    
start_time = time.time()    
cnt = 0
# Take only the first 8 sessions: CCDb only
if DATASET_NAME == 'ccdb':
    input_features_path = input_features_dir + '/*_*_*_*.csv'
else:
    input_features_path = input_features_dir + '/*.csv'
    
for feature_file in sorted(glob.glob(input_features_path)):
    
    sessid = feature_file.split('/')[-1].split('.')[0]
    print(f'Processing {sessid}')
    
    org_df = pd.read_csv(feature_file)
    print(f'\tOriginal dataframe length: {len(org_df)}')
    
    # Resample feature dataframe to common frame rate, if needed
    csv_frame_rate = (org_df.shape[0] - 1) / np.sum(np.diff(org_df[' timestamp']))
    print(f'\tcsv frame rate: {csv_frame_rate}')
    if round(csv_frame_rate) == FRAME_RATE:
        print(f'\tNOT resampling')
        new_df = org_df.copy()
    else:
        print(f'\tREsampling from {csv_frame_rate} to {FRAME_RATE}')
        new_df = []
        timestamps_resampled = np.arange(0., org_df.iloc[-1][' timestamp'], step=1. / FRAME_RATE)
        for col_name in org_df.columns:            
            # Get interpolation function
            f = interpolate.interp1d(x=org_df[' timestamp'], y=org_df[col_name], kind='linear')
            new_df.append( f(timestamps_resampled) )
        new_df = pd.DataFrame(np.array(new_df).T, columns=org_df.columns) 

    # Add first and second derivatives of selected features
    diff_features = dict()
    for feature_name in diff_selected_features:
        diff_features['diff_' + feature_name] =  np.diff(new_df[feature_name], prepend=new_df[feature_name][0])
        diff_features['diff2_' + feature_name] = np.diff(diff_features['diff_' + feature_name], 
                                                         prepend=diff_features['diff_' + feature_name][0])    
    new_df = new_df.assign(**diff_features)
    print(f'\tNew dataframe length: {len(new_df)}')
    
    # Generate segments from selected features
    X_pred = get_X_segments(new_df[selected_features])
       
    # Load nod, shake, and tilt models
    for head_gesture in head_gestures:

        # Predict and use last voting strategy
        K.clear_session()
        model = load_model(f'{models_path_prefix}/{model_names[head_gesture]}')
        y_pred_probab = model.predict_proba(X_pred, batch_size=10000)[:, -1, 0]
        y_pred_NS = model.predict_classes(X_pred, batch_size=10000)[:, -1, 0]
        
        # Smooth predictions
        y_pred = scipy.signal.medfilt(y_pred_NS, kernel_size=SMOOTHING_KERNEL_SIZE).astype(int)
        
        # Add new annotation columns
        new_df[f'{head_gesture}_probab'] = y_pred_probab
        new_df[f'{head_gesture}_NS'] = y_pred_NS
        new_df[head_gesture] = y_pred
        
    # Add columns for None class
    new_df['none_NS'] = np.where((new_df['nod_NS'] == 0) & (new_df['shake_NS'] == 0) & (new_df['tilt_NS'] == 0), 1, 0)
    new_df['none'] = np.where((new_df['nod'] == 0) & (new_df['shake'] == 0) & (new_df['tilt'] == 0), 1, 0)

    # Perform fusion of predictions from 3 binary classifiers
    # 1.) Fusion scheme max_probability (choose head gesture with maximum probability prediction)
    new_df['head_gesture_max_probab_NS'] = new_df.apply(max_probab_fusion, args=('_NS',), axis=1)
    new_df['head_gesture_max_probab'] = new_df.apply(max_probab_fusion, args=('',), axis=1)
    # If you get SettingWithCopyWarning
#     new_df = new_df.assign(head_gesture_max_probab=new_df.apply(max_probab_fusion, axis=1).values)
    
    # 2.) Fusion scheme unique (if 2 or 3 classifiers detect a head gesture, then assign none/other class)
    new_df['head_gesture_unique_NS'] = new_df.apply(unique_fusion, args=('_NS',), axis=1)
    new_df['head_gesture_unique'] = new_df.apply(unique_fusion, args=('',), axis=1)
    
    # Save as new annotated dataframe
#     print(new_df)
    new_df.to_csv(f'{output_dir}/{sessid}.csv', index=False)
    cnt += 1
    print(f'Time taken: {time.time() - start_time} s\n')        
#     break

print(f'\nGenerated {cnt} annotated feature files, using HGD.')
# Out:
# Using TensorFlow backend.
# Dataset: mimicry
# Processing sessid_01_P1_sid_09
# 	Original dataframe length: 35248
# 	csv frame rate: 58.04774977890571
# 	REsampling from 58.04774977890571 to 30.0
# 	New dataframe length: 18217
# WARNING:tensorflow:From /home/ICT2000/jondras/anaconda3/envs/dvra/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ICT2000/jondras/anaconda3/envs/dvra/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ICT2000/jondras/anaconda3/envs/dvra/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Time taken: 56.33326029777527 s
#
# Processing sessid_01_P2_sid_02
# 	Original dataframe length: 35248
# 	csv frame rate: 58.04774977890571
# 	REsampling from 58.04774977890571 to 30.0
# 	New dataframe length: 18217
# Time taken: 110.34635281562805 s
#
# Processing sessid_02_P1_sid_09
# 	Original dataframe length: 57269
# 	csv frame rate: 58.04775549962648
# 	REsampling from 58.04775549962648 to 30.0
# 	New dataframe length: 29598
# Time taken: 196.27830505371094 s
#
# Processing sessid_02_P2_sid_17
# 	Original dataframe length: 57269
# 	csv frame rate: 58.04775549962648
# 	REsampling from 58.04775549962648 to 30.0
# 	New dataframe length: 29598
# Time taken: 284.0788023471832 s
#
# Processing sessid_03_P1_sid_17
# 	Original dataframe length: 25805
# 	csv frame rate: 58.047695211357585
# 	REsampling from 58.047695211357585 to 30.0
# 	New dataframe length: 13336
# Time taken: 326.6257438659668 s
#
# Processing sessid_03_P2_sid_02
# 	Original dataframe length: 25805
# 	csv frame rate: 58.047695211357585
# 	REsampling from 58.047695211357585 to 30.0
# 	New dataframe length: 13336
# Time taken: 369.074586391449 s
#
# Processing sessid_04_P1_sid_12
# 	Original dataframe length: 55399
# 	csv frame rate: 58.04776434690764
# 	REsampling from 58.04776434690764 to 30.0
# 	New dataframe length: 28631
# Time taken: 451.51998591423035 s
#
# Processing sessid_04_P2_sid_23
# 	Original dataframe length: 55399
# 	csv frame rate: 58.04776434690764
# 	REsampling from 58.04776434690764 to 30.0
# 	New dataframe length: 28631
# Time taken: 533.7479124069214 s
#
# Processing sessid_05_P1_sid_12
# 	Original dataframe length: 56687
# 	csv frame rate: 58.047741979087405
# 	REsampling from 58.047741979087405 to 30.0
# 	New dataframe length: 29297
# Time taken: 616.0551071166992 s
#
# Processing sessid_05_P2_sid_21
# 	Original dataframe length: 56687
# 	csv frame rate: 58.047741979087405
# 	REsampling from 58.047741979087405 to 30.0
# 	New dataframe length: 29297
# Time taken: 702.7785124778748 s
#
# Processing sessid_06_P1_sid_23
# 	Original dataframe length: 56162
# 	csv frame rate: 58.04772521258464
# 	REsampling from 58.04772521258464 to 30.0
# 	New dataframe length: 29025
# Time taken: 792.9908194541931 s
#
# Processing sessid_06_P2_sid_21
# 	Original dataframe length: 56162
# 	csv frame rate: 58.04772521258464
# 	REsampling from 58.04772521258464 to 30.0
# 	New dataframe length: 29025
# Time taken: 876.4814853668213 s
#
# Processing sessid_07_P1_sid_09
# 	Original dataframe length: 54675
# 	csv frame rate: 58.04773431859685
# 	REsampling from 58.04773431859685 to 30.0
# 	New dataframe length: 28257
# Time taken: 955.298182964325 s
#
# Processing sessid_07_P2_sid_01
# 	Original dataframe length: 54675
# 	csv frame rate: 58.04773431859685
# 	REsampling from 58.04773431859685 to 30.0
# 	New dataframe length: 28257
# Time taken: 1036.969398021698 s
#
# Processing sessid_08_P1_sid_09
# 	Original dataframe length: 55693
# 	csv frame rate: 58.04775191600733
# 	REsampling from 58.04775191600733 to 30.0
# 	New dataframe length: 28783
# Time taken: 1118.429604768753 s
#
# Processing sessid_08_P2_sid_04
# 	Original dataframe length: 55693
# 	csv frame rate: 58.04775191600733
# 	REsampling from 58.04775191600733 to 30.0
# 	New dataframe length: 28783
# Time taken: 1196.2925395965576 s
#
# Processing sessid_09_P1_sid_01
# 	Original dataframe length: 56132
# 	csv frame rate: 58.047736251008295
# 	REsampling from 58.047736251008295 to 30.0
# 	New dataframe length: 29010
# Time taken: 1277.9315416812897 s
#
# Processing sessid_09_P2_sid_04
# 	Original dataframe length: 56132
# 	csv frame rate: 58.047736251008295
# 	REsampling from 58.047736251008295 to 30.0
# 	New dataframe length: 29010
# Time taken: 1356.6502149105072 s
#
# Processing sessid_10_P1_sid_09
# 	Original dataframe length: 56472
# 	csv frame rate: 58.04775106209982
# 	REsampling from 58.04775106209982 to 30.0
# 	New dataframe length: 29186
# Time taken: 1441.6262772083282 s
#
# Processing sessid_10_P2_sid_34
# 	Original dataframe length: 56472
# 	csv frame rate: 58.04775106209982
# 	REsampling from 58.04775106209982 to 30.0
# 	New dataframe length: 29186
# Time taken: 1523.2459857463837 s
#
# Processing sessid_11_P1_sid_09
# 	Original dataframe length: 54455
# 	csv frame rate: 58.04773529192295
# 	REsampling from 58.04773529192295 to 30.0
# 	New dataframe length: 28143
# Time taken: 1602.2340202331543 s
#
# Processing sessid_11_P2_sid_15
# 	Original dataframe length: 54455
# 	csv frame rate: 58.04773529192295
# 	REsampling from 58.04773529192295 to 30.0
# 	New dataframe length: 28143
# Time taken: 1681.1680841445923 s
#
# Processing sessid_12_P1_sid_15
# 	Original dataframe length: 32847
# 	csv frame rate: 58.04769857469802
# 	REsampling from 58.04769857469802 to 30.0
# 	New dataframe length: 16976
# Time taken: 1731.6915555000305 s
#
# Processing sessid_12_P2_sid_11
# 	Original dataframe length: 32847
# 	csv frame rate: 58.04769857469802
# 	REsampling from 58.04769857469802 to 30.0
# 	New dataframe length: 16976
# Time taken: 1781.8563973903656 s
#
# Processing sessid_13_P1_sid_09
# 	Original dataframe length: 50674
# 	csv frame rate: 58.04773218290998
# 	REsampling from 58.04773218290998 to 30.0
# 	New dataframe length: 26189
# Time taken: 1856.7251765727997 s
#
# Processing sessid_13_P2_sid_19
# 	Original dataframe length: 50674
# 	csv frame rate: 58.04773218290998
# 	REsampling from 58.04773218290998 to 30.0
# 	New dataframe length: 26189
# Time taken: 1930.1234340667725 s
#
# Processing sessid_14_P1_sid_19
# 	Original dataframe length: 40438
# 	csv frame rate: 58.047762325298294
# 	REsampling from 58.047762325298294 to 30.0
# 	New dataframe length: 20899
# Time taken: 1990.1776134967804 s
#
# Processing sessid_14_P2_sid_06
# 	Original dataframe length: 40438
# 	csv frame rate: 58.047762325298294
# 	REsampling from 58.047762325298294 to 30.0
# 	New dataframe length: 20899
# Time taken: 2051.2821934223175 s
#
# Processing sessid_15_P1_sid_09
# 	Original dataframe length: 59435
# 	csv frame rate: 58.0477614097732
# 	REsampling from 58.0477614097732 to 30.0
# 	New dataframe length: 30717
# Time taken: 2137.060168027878 s
#
# Processing sessid_15_P2_sid_16
# 	Original dataframe length: 59435
# 	csv frame rate: 58.0477614097732
# 	REsampling from 58.0477614097732 to 30.0
# 	New dataframe length: 30717
# Time taken: 2220.479960203171 s
#
# Processing sessid_16_P1_sid_24
# 	Original dataframe length: 62013
# 	csv frame rate: 58.04774532829476
# 	REsampling from 58.04774532829476 to 30.0
# 	New dataframe length: 32049
# Time taken: 2309.515719652176 s
#
# Processing sessid_16_P2_sid_16
# 	Original dataframe length: 62013
# 	csv frame rate: 58.04774532829476
# 	REsampling from 58.04774532829476 to 30.0
# 	New dataframe length: 32049
# Time taken: 2396.481517791748 s
#
# Processing sessid_17_P1_sid_09
# 	Original dataframe length: 35923
# 	csv frame rate: 58.04778333481461
# 	REsampling from 58.04778333481461 to 30.0
# 	New dataframe length: 18566
# Time taken: 2448.9874505996704 s
#
# Processing sessid_17_P2_sid_43
# 	Original dataframe length: 35923
# 	csv frame rate: 58.04778333481461
# 	REsampling from 58.04778333481461 to 30.0
# 	New dataframe length: 18566
# Time taken: 2501.7741594314575 s
#
# Processing sessid_18_P1_sid_03
# 	Original dataframe length: 32813
# 	csv frame rate: 58.04772679426599
# 	REsampling from 58.04772679426599 to 30.0
# 	New dataframe length: 16958
# Time taken: 2550.7428731918335 s
#
# Processing sessid_18_P2_sid_43
# 	Original dataframe length: 32813
# 	csv frame rate: 58.04772679426599
# 	REsampling from 58.04772679426599 to 30.0
# 	New dataframe length: 16958
# Time taken: 2599.2124400138855 s
#
# Processing sessid_19_P1_sid_09
# 	Original dataframe length: 52669
# 	csv frame rate: 58.04774931060858
# 	REsampling from 58.04774931060858 to 30.0
# 	New dataframe length: 27220
# Time taken: 2672.972610473633 s
#
# Processing sessid_19_P2_sid_22
# 	Original dataframe length: 52669
# 	csv frame rate: 58.04774931060858
# 	REsampling from 58.04774931060858 to 30.0
# 	New dataframe length: 27220
# Time taken: 2748.9933512210846 s
#
# Processing sessid_20_P1_sid_09
# 	Original dataframe length: 48250
# 	csv frame rate: 58.04775052785447
# 	REsampling from 58.04775052785447 to 30.0
# 	New dataframe length: 24936
# Time taken: 2818.7101485729218 s
#
# Processing sessid_20_P2_sid_50
# 	Original dataframe length: 48250
# 	csv frame rate: 58.04775052785447
# 	REsampling from 58.04775052785447 to 30.0
# 	New dataframe length: 24936
# Time taken: 2888.3692269325256 s
#
# Processing sessid_21_P1_sid_50
# 	Original dataframe length: 35024
# 	csv frame rate: 58.04776016494626
# 	REsampling from 58.04776016494626 to 30.0
# 	New dataframe length: 18101
# Time taken: 2940.758770942688 s
#
# Processing sessid_21_P2_sid_22
# 	Original dataframe length: 35024
# 	csv frame rate: 58.04776016494626
# 	REsampling from 58.04776016494626 to 30.0
# 	New dataframe length: 18101
# Time taken: 2992.554641008377 s
#
# Processing sessid_22_P1_sid_12
# 	Original dataframe length: 51116
# 	csv frame rate: 58.04776008212881
# 	REsampling from 58.04776008212881 to 30.0
# 	New dataframe length: 26418
# Time taken: 3068.6187992095947 s
#
# Processing sessid_22_P2_sid_18
# 	Original dataframe length: 51116
# 	csv frame rate: 58.04776008212881
# 	REsampling from 58.04776008212881 to 30.0
# 	New dataframe length: 26418
# Time taken: 3143.658897638321 s
#
# Processing sessid_23_P1_sid_12
# 	Original dataframe length: 53106
# 	csv frame rate: 58.047767393561784
# 	REsampling from 58.047767393561784 to 30.0
# 	New dataframe length: 27446
# Time taken: 3221.152349472046 s
#
# Processing sessid_23_P2_sid_39
# 	Original dataframe length: 53106
# 	csv frame rate: 58.047767393561784
# 	REsampling from 58.047767393561784 to 30.0
# 	New dataframe length: 27446
# Time taken: 3298.2204370498657 s
#
# Processing sessid_24_P1_sid_18
# 	Original dataframe length: 26306
# 	csv frame rate: 58.047801995317336
# 	REsampling from 58.047801995317336 to 30.0
# 	New dataframe length: 13595
# Time taken: 3340.3601377010345 s
#
# Processing sessid_24_P2_sid_39
# 	Original dataframe length: 26306
# 	csv frame rate: 58.047801995317336
# 	REsampling from 58.047801995317336 to 30.0
# 	New dataframe length: 13595
# Time taken: 3381.8307962417603 s
#
# Processing sessid_25_P1_sid_12
# 	Original dataframe length: 47325
# 	csv frame rate: 58.04773937148885
# 	REsampling from 58.04773937148885 to 30.0
# 	New dataframe length: 24458
# Time taken: 3450.7930603027344 s
#
# Processing sessid_25_P2_sid_27
# 	Original dataframe length: 47325
# 	csv frame rate: 58.04773937148885
# 	REsampling from 58.04773937148885 to 30.0
# 	New dataframe length: 24458
# Time taken: 3520.555448770523 s
#
# Processing sessid_26_P1_sid_12
# 	Original dataframe length: 28301
# 	csv frame rate: 58.04770988451993
# 	REsampling from 58.04770988451993 to 30.0
# 	New dataframe length: 14626
# Time taken: 3564.3573174476624 s
#
# Processing sessid_26_P2_sid_32
# 	Original dataframe length: 28301
# 	csv frame rate: 58.04770988451993
# 	REsampling from 58.04770988451993 to 30.0
# 	New dataframe length: 14626
# Time taken: 3608.1914422512054 s
#
# Processing sessid_27_P1_sid_27
# 	Original dataframe length: 33327
# 	csv frame rate: 58.047704811239576
# 	REsampling from 58.047704811239576 to 30.0
# 	New dataframe length: 17224
# Time taken: 3659.13937830925 s
#
# Processing sessid_27_P2_sid_32
# 	Original dataframe length: 33327
# 	csv frame rate: 58.047704811239576
# 	REsampling from 58.047704811239576 to 30.0
# 	New dataframe length: 17224
# Time taken: 3709.8545174598694 s
#
# Processing sessid_28_P1_sid_09
# 	Original dataframe length: 54964
# 	csv frame rate: 58.04771354552262
# 	REsampling from 58.04771354552262 to 30.0
# 	New dataframe length: 28406
# Time taken: 3789.1905868053436 s
#
# Processing sessid_28_P2_sid_07
# 	Original dataframe length: 54964
# 	csv frame rate: 58.04771354552262
# 	REsampling from 58.04771354552262 to 30.0
# 	New dataframe length: 28406
# Time taken: 3869.250682592392 s
#
# Processing sessid_29_P1_sid_09
# 	Original dataframe length: 45389
# 	csv frame rate: 58.04774986315525
# 	REsampling from 58.04774986315525 to 30.0
# 	New dataframe length: 23458
# Time taken: 3935.8587639331818 s
#
# Processing sessid_29_P2_sid_05
# 	Original dataframe length: 45389
# 	csv frame rate: 58.04774986315525
# 	REsampling from 58.04774986315525 to 30.0
# 	New dataframe length: 23458
# Time taken: 4001.0922045707703 s
#
# Processing sessid_30_P1_sid_07
# 	Original dataframe length: 12772
# 	csv frame rate: 58.04762532441854
# 	REsampling from 58.04762532441854 to 30.0
# 	New dataframe length: 6601
# Time taken: 4024.5755240917206 s
#
# Processing sessid_30_P2_sid_05
# 	Original dataframe length: 12772
# 	csv frame rate: 58.04762532441854
# 	REsampling from 58.04762532441854 to 30.0
# 	New dataframe length: 6601
# Time taken: 4047.568067550659 s
#
# Processing sessid_31_P1_sid_28
# 	Original dataframe length: 50004
# 	csv frame rate: 58.047717004174544
# 	REsampling from 58.047717004174544 to 30.0
# 	New dataframe length: 25843
# Time taken: 4121.333716869354 s
#
# Processing sessid_31_P2_sid_09
# 	Original dataframe length: 50004
# 	csv frame rate: 58.047717004174544
# 	REsampling from 58.047717004174544 to 30.0
# 	New dataframe length: 25843
# Time taken: 4194.1023206710815 s
#
# Processing sessid_32_P1_sid_28
# 	Original dataframe length: 36887
# 	csv frame rate: 58.047784062117394
# 	REsampling from 58.047784062117394 to 30.0
# 	New dataframe length: 19064
# Time taken: 4250.917355298996 s
#
# Processing sessid_32_P2_sid_14
# 	Original dataframe length: 36887
# 	csv frame rate: 58.047784062117394
# 	REsampling from 58.047784062117394 to 30.0
# 	New dataframe length: 19064
# Time taken: 4306.468861341476 s
#
# Processing sessid_33_P1_sid_09
# 	Original dataframe length: 55898
# 	csv frame rate: 58.04772630741608
# 	REsampling from 58.04772630741608 to 30.0
# 	New dataframe length: 28889
# Time taken: 4386.490909576416 s
#
# Processing sessid_33_P2_sid_33
# 	Original dataframe length: 55898
# 	csv frame rate: 58.04772630741608
# 	REsampling from 58.04772630741608 to 30.0
# 	New dataframe length: 28889
# Time taken: 4468.6046624183655 s
#
# Processing sessid_34_P1_sid_09
# 	Original dataframe length: 49719
# 	csv frame rate: 58.04773368888806
# 	REsampling from 58.04773368888806 to 30.0
# 	New dataframe length: 25696
# Time taken: 4541.059882879257 s
#
# Processing sessid_34_P2_sid_36
# 	Original dataframe length: 49719
# 	csv frame rate: 58.04773368888806
# 	REsampling from 58.04773368888806 to 30.0
# 	New dataframe length: 25696
# Time taken: 4612.891644477844 s
#
# Processing sessid_35_P1_sid_33
# 	Original dataframe length: 58124
# 	csv frame rate: 58.04771211738375
# 	REsampling from 58.04771211738375 to 30.0
# 	New dataframe length: 30039
# Time taken: 4693.580398797989 s
#
# Processing sessid_35_P2_sid_36
# 	Original dataframe length: 58124
# 	csv frame rate: 58.04771211738375
# 	REsampling from 58.04771211738375 to 30.0
# 	New dataframe length: 30039
# Time taken: 4777.706176280975 s
#
# Processing sessid_36_P1_sid_13
# 	Original dataframe length: 52514
# 	csv frame rate: 58.0477354828155
# 	REsampling from 58.0477354828155 to 30.0
# 	New dataframe length: 27140
# Time taken: 4852.904762268066 s
#
# Processing sessid_36_P2_sid_40
# 	Original dataframe length: 52514
# 	csv frame rate: 58.0477354828155
# 	REsampling from 58.0477354828155 to 30.0
# 	New dataframe length: 27140
# Time taken: 4929.4680824279785 s
#
# Processing sessid_37_P1_sid_13
# 	Original dataframe length: 47797
# 	csv frame rate: 58.04775616930473
# 	REsampling from 58.04775616930473 to 30.0
# 	New dataframe length: 24702
# Time taken: 4999.375800609589 s
#
# Processing sessid_37_P2_sid_40
# 	Original dataframe length: 47797
# 	csv frame rate: 58.04775616930473
# 	REsampling from 58.04775616930473 to 30.0
# 	New dataframe length: 24702
# Time taken: 5070.188827753067 s
#
# Processing sessid_38_P1_sid_56
# 	Original dataframe length: 64726
# 	csv frame rate: 58.04771347164339
# 	REsampling from 58.04771347164339 to 30.0
# 	New dataframe length: 33451
# Time taken: 5162.191763877869 s
#
# Processing sessid_38_P2_sid_30
# 	Original dataframe length: 64726
# 	csv frame rate: 58.04771347164339
# 	REsampling from 58.04771347164339 to 30.0
# 	New dataframe length: 33451
# Time taken: 5255.163265943527 s
#
# Processing sessid_40_P1_sid_56
# 	Original dataframe length: 50725
# 	csv frame rate: 58.04777119629402
# 	REsampling from 58.04777119629402 to 30.0
# 	New dataframe length: 26215
# Time taken: 5330.280802488327 s
#
# Processing sessid_40_P2_sid_51
# 	Original dataframe length: 50725
# 	csv frame rate: 58.04777119629402
# 	REsampling from 58.04777119629402 to 30.0
# 	New dataframe length: 26215
# Time taken: 5404.6622014045715 s
#
# Processing sessid_41_P1_sid_57
# 	Original dataframe length: 38977
# 	csv frame rate: 58.047768476141826
# 	REsampling from 58.047768476141826 to 30.0
# 	New dataframe length: 20144
# Time taken: 5464.2672646045685 s
#
# Processing sessid_41_P2_sid_51
# 	Original dataframe length: 38977
# 	csv frame rate: 58.047768476141826
# 	REsampling from 58.047768476141826 to 30.0
# 	New dataframe length: 20144
# Time taken: 5523.161546707153 s
#
# Processing sessid_42_P1_sid_12
# 	Original dataframe length: 42660
# 	csv frame rate: 58.0477483177869
# 	REsampling from 58.0477483177869 to 30.0
# 	New dataframe length: 22047
# Time taken: 5584.922510623932 s
#
# Processing sessid_42_P2_sid_10
# 	Original dataframe length: 42660
# 	csv frame rate: 58.0477483177869
# 	REsampling from 58.0477483177869 to 30.0
# 	New dataframe length: 22047
# Time taken: 5647.081107854843 s
#
# Processing sessid_43_P1_sid_12
# 	Original dataframe length: 45690
# 	csv frame rate: 58.04770459436865
# 	REsampling from 58.04770459436865 to 30.0
# 	New dataframe length: 23613
# Time taken: 5712.074960708618 s
#
# Processing sessid_43_P2_sid_20
# 	Original dataframe length: 45690
# 	csv frame rate: 58.04770459436865
# 	REsampling from 58.04770459436865 to 30.0
# 	New dataframe length: 23613
# Time taken: 5777.891512155533 s
#
# Processing sessid_44_P1_sid_10
# 	Original dataframe length: 18217
# 	csv frame rate: 58.04767837966165
# 	REsampling from 58.04767837966165 to 30.0
# 	New dataframe length: 9415
# Time taken: 5807.465927600861 s
#
# Processing sessid_44_P2_sid_20
# 	Original dataframe length: 18217
# 	csv frame rate: 58.04767837966165
# 	REsampling from 58.04767837966165 to 30.0
# 	New dataframe length: 9415
# Time taken: 5837.3002343177795 s
#
# Processing sessid_45_P1_sid_56
# 	Original dataframe length: 60468
# 	csv frame rate: 58.047744166377875
# 	REsampling from 58.047744166377875 to 30.0
# 	New dataframe length: 31251
# Time taken: 5922.215509414673 s
#
# Processing sessid_45_P2_sid_38
# 	Original dataframe length: 60468
# 	csv frame rate: 58.047744166377875
# 	REsampling from 58.047744166377875 to 30.0
# 	New dataframe length: 31251
# Time taken: 6007.564825534821 s
#
# Processing sessid_46_P1_sid_55
# 	Original dataframe length: 18615
# 	csv frame rate: 58.04775670711361
# 	REsampling from 58.04775670711361 to 30.0
# 	New dataframe length: 9621
# Time taken: 6038.398245334625 s
#
# Processing sessid_46_P2_sid_38
# 	Original dataframe length: 18615
# 	csv frame rate: 58.04775670711361
# 	REsampling from 58.04775670711361 to 30.0
# 	New dataframe length: 9621
# Time taken: 6068.793109893799 s
#
# Processing sessid_47_P1_sid_56
# 	Original dataframe length: 57086
# 	csv frame rate: 58.04772146042109
# 	REsampling from 58.04772146042109 to 30.0
# 	New dataframe length: 29503
# Time taken: 6150.011506319046 s
#
# Processing sessid_47_P2_sid_37
# 	Original dataframe length: 57086
# 	csv frame rate: 58.04772146042109
# 	REsampling from 58.04772146042109 to 30.0
# 	New dataframe length: 29503
# Time taken: 6230.504379272461 s
#
# Processing sessid_48_P1_sid_58
# 	Original dataframe length: 46253
# 	csv frame rate: 58.04777156397153
# 	REsampling from 58.04777156397153 to 30.0
# 	New dataframe length: 23904
# Time taken: 6297.1493537425995 s
#
# Processing sessid_48_P2_sid_37
# 	Original dataframe length: 46253
# 	csv frame rate: 58.04777156397153
# 	REsampling from 58.04777156397153 to 30.0
# 	New dataframe length: 23904
# Time taken: 6363.881395578384 s
#
# Processing sessid_49_P1_sid_56
# 	Original dataframe length: 51071
# 	csv frame rate: 58.04774532191095
# 	REsampling from 58.04774532191095 to 30.0
# 	New dataframe length: 26394
# Time taken: 6432.586111783981 s
#
# Processing sessid_49_P2_sid_49
# 	Original dataframe length: 51071
# 	csv frame rate: 58.04774532191095
# 	REsampling from 58.04774532191095 to 30.0
# 	New dataframe length: 26394
# Time taken: 6505.014268875122 s
#
# Processing sessid_50_P1_sid_12
# 	Original dataframe length: 49768
# 	csv frame rate: 58.04774268498366
# 	REsampling from 58.04774268498366 to 30.0
# 	New dataframe length: 25721
# Time taken: 6576.166508436203 s
#
# Processing sessid_50_P2_sid_31
# 	Original dataframe length: 49768
# 	csv frame rate: 58.04774268498366
# 	REsampling from 58.04774268498366 to 30.0
# 	New dataframe length: 25721
# Time taken: 6647.517818450928 s
#
# Processing sessid_51_P1_sid_12
# 	Original dataframe length: 37588
# 	csv frame rate: 58.04771751871374
# 	REsampling from 58.04771751871374 to 30.0
# 	New dataframe length: 19426
# Time taken: 6702.392196893692 s
#
# Processing sessid_51_P2_sid_59
# 	Original dataframe length: 37588
# 	csv frame rate: 58.04771751871374
# 	REsampling from 58.04771751871374 to 30.0
# 	New dataframe length: 19426
# Time taken: 6757.246301412582 s
#
# Processing sessid_52_P1_sid_12
# 	Original dataframe length: 38868
# 	csv frame rate: 58.04770225667219
# 	REsampling from 58.04770225667219 to 30.0
# 	New dataframe length: 20088
# Time taken: 6813.562660455704 s
#
# Processing sessid_52_P2_sid_08
# 	Original dataframe length: 38868
# 	csv frame rate: 58.04770225667219
# 	REsampling from 58.04770225667219 to 30.0
# 	New dataframe length: 20088
# Time taken: 6872.269691705704 s
#
# Processing sessid_53_P1_sid_59
# 	Original dataframe length: 19902
# 	csv frame rate: 58.0476550217449
# 	REsampling from 58.0476550217449 to 30.0
# 	New dataframe length: 10286
# Time taken: 6904.137801647186 s
#
# Processing sessid_53_P2_sid_08
# 	Original dataframe length: 19902
# 	csv frame rate: 58.0476550217449
# 	REsampling from 58.0476550217449 to 30.0
# 	New dataframe length: 10286
# Time taken: 6936.117717504501 s
#
# Processing sessid_54_P1_sid_12
# 	Original dataframe length: 42980
# 	csv frame rate: 58.04772503808711
# 	REsampling from 58.04772503808711 to 30.0
# 	New dataframe length: 22213
# Time taken: 6996.510129928589 s
#
# Processing sessid_54_P2_sid_60
# 	Original dataframe length: 42980
# 	csv frame rate: 58.04772503808711
# 	REsampling from 58.04772503808711 to 30.0
# 	New dataframe length: 22213
# Time taken: 7059.003969907761 s
#
#
# Generated 106 annotated feature files, using HGD.

# %%
# Log from running on CCDb
# Out:
# Using TensorFlow backend.
# Dataset: ccdb
# Processing P1_P2_1402_C1
# 	Original dataframe length: 8821
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 8821
# WARNING:tensorflow:From /home/ICT2000/jondras/anaconda3/envs/dvra/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/ICT2000/jondras/anaconda3/envs/dvra/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From /home/ICT2000/jondras/anaconda3/envs/dvra/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Time taken: 24.030054330825806 s
#
# Processing P1_P2_1402_C2
# 	Original dataframe length: 8821
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 8821
# Time taken: 44.7995080947876 s
#
# Processing P1_P3_1502_C1
# 	Original dataframe length: 9805
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 9805
# Time taken: 66.95227527618408 s
#
# Processing P1_P3_1502_C2
# 	Original dataframe length: 8915
# 	csv frame rate: 30.000033654962593
# 	NOT resampling
# 	New dataframe length: 8915
# Time taken: 87.89469242095947 s
#
# Processing P3_P4_1502_C1
# 	Original dataframe length: 8901
# 	csv frame rate: 29.9999662921727
# 	NOT resampling
# 	New dataframe length: 8901
# Time taken: 108.90174794197083 s
#
# Processing P3_P4_1502_C2
# 	Original dataframe length: 8901
# 	csv frame rate: 29.9999662921727
# 	NOT resampling
# 	New dataframe length: 8901
# Time taken: 129.6006736755371 s
#
# Processing P5_P2_1003_C1
# 	Original dataframe length: 8571
# 	csv frame rate: 29.99996499420654
# 	NOT resampling
# 	New dataframe length: 8571
# Time taken: 149.24264287948608 s
#
# Processing P5_P2_1003_C2
# 	Original dataframe length: 8571
# 	csv frame rate: 29.99996499420654
# 	NOT resampling
# 	New dataframe length: 8571
# Time taken: 168.86031866073608 s
#
# Processing P5_P3_2202_C1
# 	Original dataframe length: 8951
# 	csv frame rate: 30.000033519590527
# 	NOT resampling
# 	New dataframe length: 8951
# Time taken: 189.7152554988861 s
#
# Processing P5_P3_2202_C2
# 	Original dataframe length: 8951
# 	csv frame rate: 30.000033519590527
# 	NOT resampling
# 	New dataframe length: 8951
# Time taken: 210.6310601234436 s
#
# Processing P6_P2_1602_C1
# 	Original dataframe length: 8851
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 8851
# Time taken: 230.7150104045868 s
#
# Processing P6_P2_1602_C2
# 	Original dataframe length: 8851
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 8851
# Time taken: 251.04770612716675 s
#
# Processing P6_P3_1602_C1
# 	Original dataframe length: 8825
# 	csv frame rate: 30.000033998225295
# 	NOT resampling
# 	New dataframe length: 8825
# Time taken: 271.232754945755 s
#
# Processing P6_P3_1602_C2
# 	Original dataframe length: 8825
# 	csv frame rate: 30.000033998225295
# 	NOT resampling
# 	New dataframe length: 8825
# Time taken: 291.70590901374817 s
#
# Processing P6_P4_1602_C1
# 	Original dataframe length: 8941
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 8941
# Time taken: 311.96200466156006 s
#
# Processing P6_P4_1602_C2
# 	Original dataframe length: 8941
# 	csv frame rate: 30.0
# 	NOT resampling
# 	New dataframe length: 8941
# Time taken: 332.00792384147644 s
#
#
# Generated 16 annotated feature files, using HGD.
