# %%
#######################################################################################################################
# Project: Deep Virtual Rapport Agent (head gesture detector)
#
#     Jan Ondras (jo951030@gmail.com)
#     Institute for Creative Technologies, University of Southern California
#     April-October 2019
#
#######################################################################################################################
#
#     Show training history of Head Gesture Detector (HGD) models from every training setting (TS1, TS2, TS3).
#
#     See the report ./Report_head_gesture_detector.odt for more details.
#
#######################################################################################################################

# %% [markdown]
# # Training history for TS1:
# ### Nod HGD models trained on one of the vra1, hatice2010, sewa, and nvb datasets at a time.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/*_nod_32ws_12f_4u.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: hatice2010_nod_32ws_12f_4u.pkl
#
# 	[last] Max train bacc: 0.9041 @epoch 33
# 	[last] Max val bacc: 0.8798 @epoch 26
#
# 	[majority] Max train bacc: 0.8950 @epoch 33
# 	[majority] Max val bacc: 0.8205 @epoch 33
# Loading: nvb_nod_32ws_12f_4u.pkl
#
# 	[last] Max train bacc: 0.8217 @epoch 29
# 	[last] Max val bacc: 0.8209 @epoch 21
#
# 	[majority] Max train bacc: 0.8217 @epoch 31
# 	[majority] Max val bacc: 0.8272 @epoch 21
# Loading: sewa_nod_32ws_12f_4u.pkl
#
# 	[last] Max train bacc: 0.8043 @epoch 36
# 	[last] Max val bacc: 0.7784 @epoch 27
#
# 	[majority] Max train bacc: 0.7881 @epoch 33
# 	[majority] Max val bacc: 0.7701 @epoch 25
# Loading: vra1_nod_32ws_12f_4u.pkl
#
# 	[last] Max train bacc: 0.8752 @epoch 36
# 	[last] Max val bacc: 0.8595 @epoch 27
#
# 	[majority] Max train bacc: 0.8706 @epoch 36
# 	[majority] Max val bacc: 0.8588 @epoch 27

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/*_nod_32ws_12f_8u.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: hatice2010_nod_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.9260 @epoch 63
# 	[last] Max val bacc: 0.8940 @epoch 53
#
# 	[majority] Max train bacc: 0.9155 @epoch 63
# 	[majority] Max val bacc: 0.8301 @epoch 53
# Loading: nvb_nod_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8350 @epoch 14
# 	[last] Max val bacc: 0.8263 @epoch 4
#
# 	[majority] Max train bacc: 0.8337 @epoch 14
# 	[majority] Max val bacc: 0.8317 @epoch 4
# Loading: sewa_nod_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8378 @epoch 52
# 	[last] Max val bacc: 0.7886 @epoch 44
#
# 	[majority] Max train bacc: 0.8200 @epoch 51
# 	[majority] Max val bacc: 0.7795 @epoch 42
# Loading: vra1_nod_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8905 @epoch 17
# 	[last] Max val bacc: 0.8475 @epoch 9
#
# 	[majority] Max train bacc: 0.8867 @epoch 17
# 	[majority] Max val bacc: 0.8484 @epoch 7

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/*_nod_32ws_12f_16u.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: 4comb_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8567 @epoch 14
# 	[last] Max val bacc: 0.8323 @epoch 5
#
# 	[majority] Max train bacc: 0.8467 @epoch 12
# 	[majority] Max val bacc: 0.8280 @epoch 13
# Loading: hatice2010_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.9323 @epoch 41
# 	[last] Max val bacc: 0.8796 @epoch 32
#
# 	[majority] Max train bacc: 0.9222 @epoch 41
# 	[majority] Max val bacc: 0.8231 @epoch 18
# Loading: nvb_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8663 @epoch 12
# 	[last] Max val bacc: 0.8200 @epoch 2
#
# 	[majority] Max train bacc: 0.8622 @epoch 12
# 	[majority] Max val bacc: 0.8242 @epoch 9
# Loading: sewa_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8656 @epoch 17
# 	[last] Max val bacc: 0.7884 @epoch 8
#
# 	[majority] Max train bacc: 0.8447 @epoch 18
# 	[majority] Max val bacc: 0.7850 @epoch 14
# Loading: vra1_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.9223 @epoch 27
# 	[last] Max val bacc: 0.8679 @epoch 17
#
# ...

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/*_nod_32ws_12f_32u.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: 4comb_nod_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.8944 @epoch 10
# 	[last] Max val bacc: 0.8398 @epoch 0
#
# 	[majority] Max train bacc: 0.8814 @epoch 9
# 	[majority] Max val bacc: 0.8316 @epoch 0
# Loading: hatice2010_nod_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.9444 @epoch 48
# 	[last] Max val bacc: 0.8913 @epoch 39
#
# 	[majority] Max train bacc: 0.9342 @epoch 48
# 	[majority] Max val bacc: 0.8262 @epoch 22
# Loading: nvb_nod_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.9155 @epoch 11
# 	[last] Max val bacc: 0.8207 @epoch 1
#
# 	[majority] Max train bacc: 0.9059 @epoch 11
# 	[majority] Max val bacc: 0.8259 @epoch 1
# Loading: sewa_nod_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.9204 @epoch 14
# 	[last] Max val bacc: 0.7943 @epoch 4
#
# 	[majority] Max train bacc: 0.8966 @epoch 13
# 	[majority] Max val bacc: 0.7909 @epoch 7
# Loading: vra1_nod_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.9611 @epoch 29
# 	[last] Max val bacc: 0.8635 @epoch 19
#
# ...

# %% [markdown]
# # Training history for TS2:

# %% [markdown]
# ### Nod HGD models trained on the 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/4comb_nod_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: 4comb_nod_32ws_12f_128u.pkl
#
# 	[last] Max train bacc: 0.9798 @epoch 10
# 	[last] Max val bacc: 0.8046 @epoch 0
#
# 	[majority] Max train bacc: 0.9757 @epoch 10
# 	[majority] Max val bacc: 0.8022 @epoch 0
# Loading: 4comb_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8567 @epoch 14
# 	[last] Max val bacc: 0.8323 @epoch 5
#
# 	[majority] Max train bacc: 0.8467 @epoch 12
# 	[majority] Max val bacc: 0.8280 @epoch 13
# Loading: 4comb_nod_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.8944 @epoch 10
# 	[last] Max val bacc: 0.8398 @epoch 0
#
# 	[majority] Max train bacc: 0.8814 @epoch 9
# 	[majority] Max val bacc: 0.8316 @epoch 0
# Loading: 4comb_nod_32ws_12f_64u.pkl
#
# 	[last] Max train bacc: 0.9521 @epoch 12
# 	[last] Max val bacc: 0.8192 @epoch 2
#
# 	[majority] Max train bacc: 0.9402 @epoch 12
# 	[majority] Max val bacc: 0.8214 @epoch 2
# Loading: 4comb_nod_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8236 @epoch 13
# 	[last] Max val bacc: 0.8190 @epoch 3
#
# ...

# %% [markdown]
# ### Shake HGD models trained on the 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/4comb_shake_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: 4comb_shake_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8922 @epoch 19
# 	[last] Max val bacc: 0.8588 @epoch 10
#
# 	[majority] Max train bacc: 0.8779 @epoch 19
# 	[majority] Max val bacc: 0.8335 @epoch 13
# Loading: 4comb_shake_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.9337 @epoch 14
# 	[last] Max val bacc: 0.8276 @epoch 5
#
# 	[majority] Max train bacc: 0.9189 @epoch 14
# 	[majority] Max val bacc: 0.8166 @epoch 5
# Loading: 4comb_shake_32ws_12f_4u.pkl
#
# 	[last] Max train bacc: 0.8406 @epoch 17
# 	[last] Max val bacc: 0.8540 @epoch 15
#
# 	[majority] Max train bacc: 0.8295 @epoch 22
# 	[majority] Max val bacc: 0.8323 @epoch 25
# Loading: 4comb_shake_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8671 @epoch 45
# 	[last] Max val bacc: 0.8602 @epoch 39
#
# 	[majority] Max train bacc: 0.8557 @epoch 45
# 	[majority] Max val bacc: 0.8438 @epoch 39

# %% [markdown]
# ### Tilt HGD models trained on the 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/4comb_tilt_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: 4comb_tilt_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8627 @epoch 34
# 	[last] Max val bacc: 0.8236 @epoch 24
#
# 	[majority] Max train bacc: 0.8528 @epoch 34
# 	[majority] Max val bacc: 0.8246 @epoch 31
# Loading: 4comb_tilt_32ws_12f_32u.pkl
#
# 	[last] Max train bacc: 0.8947 @epoch 13
# 	[last] Max val bacc: 0.7813 @epoch 3
#
# 	[majority] Max train bacc: 0.8809 @epoch 12
# 	[majority] Max val bacc: 0.7777 @epoch 3
# Loading: 4comb_tilt_32ws_12f_4u.pkl
#
# 	[last] Max train bacc: 0.7800 @epoch 57
# 	[last] Max val bacc: 0.8216 @epoch 47
#
# 	[majority] Max train bacc: 0.7802 @epoch 57
# 	[majority] Max val bacc: 0.8291 @epoch 38
# Loading: 4comb_tilt_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8147 @epoch 64
# 	[last] Max val bacc: 0.8215 @epoch 54
#
# 	[majority] Max train bacc: 0.8145 @epoch 64
# 	[majority] Max val bacc: 0.8296 @epoch 40

# %% [markdown]
# # Training history for TS3:

# %% [markdown]
# ### Final nod HGD models trained on the *whole* 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
# 200 epochs - not very different

from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_200epochs_4comb_nod_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_200epochs_4comb_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8745 @epoch 178
# 	[last] Max val bacc: 0.8366 @epoch 172
#
# 	[majority] Max train bacc: 0.8651 @epoch 185
# 	[majority] Max val bacc: 0.8307 @epoch 155

# %%
# default: 100 epochs

from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_4comb_nod_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_4comb_nod_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8706 @epoch 97
# 	[last] Max val bacc: 0.8363 @epoch 90
#
# 	[majority] Max train bacc: 0.8614 @epoch 93
# 	[majority] Max val bacc: 0.8295 @epoch 93

# %% [markdown]
# ### Final shake HGD models trained on the *whole* 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_4comb_shake_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_4comb_shake_32ws_12f_8u.pkl
#
# 	[last] Max train bacc: 0.8747 @epoch 93
# 	[last] Max val bacc: 0.8673 @epoch 63
#
# 	[majority] Max train bacc: 0.8627 @epoch 93
# 	[majority] Max val bacc: 0.8467 @epoch 67

# %% [markdown]
# ### Final tilt HGD models trained on the *whole* 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_4comb_tilt_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_4comb_tilt_32ws_12f_16u.pkl
#
# 	[last] Max train bacc: 0.8925 @epoch 95
# 	[last] Max val bacc: 0.8302 @epoch 42
#
# 	[majority] Max train bacc: 0.8811 @epoch 98
# 	[majority] Max val bacc: 0.8367 @epoch 75

# %% [markdown]
# ### With augmentation A1: Final nod HGD models trained on the *whole* 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_4comb_nod_*_A1_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_4comb_nod_32ws_12f_A1_16u.pkl
#
# 	[last] Max train bacc: 0.8696 @epoch 41
# 	[last] Max val bacc: 0.8274 @epoch 38
#
# 	[majority] Max train bacc: 0.8590 @epoch 97
# 	[majority] Max val bacc: 0.8239 @epoch 38

# %% [markdown]
# ### With augmentation A1: Final shake HGD models trained on the *whole* 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_4comb_shake_*_A1_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_4comb_shake_32ws_12f_A1_8u.pkl
#
# 	[last] Max train bacc: 0.8551 @epoch 38
# 	[last] Max val bacc: 0.8323 @epoch 96
#
# 	[majority] Max train bacc: 0.8431 @epoch 38
# 	[majority] Max val bacc: 0.8187 @epoch 93

# %% [markdown]
# ### With augmentation A1: Final tilt HGD models trained on the *whole* 4comb dataset.
#
# Can compare training and validation curves for various window sizes, number of features, model architectures, and evaluation metrics.

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./checkpoints/final_4comb_tilt_*_A1_*.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: final_4comb_tilt_32ws_12f_A1_16u.pkl
#
# 	[last] Max train bacc: 0.8856 @epoch 71
# 	[last] Max val bacc: 0.7459 @epoch 90
#
# 	[majority] Max train bacc: 0.8720 @epoch 97
# 	[majority] Max val bacc: 0.7714 @epoch 97
