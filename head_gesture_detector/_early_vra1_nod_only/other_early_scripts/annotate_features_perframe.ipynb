# %%
###########################################################
import numpy as np
random_seed = 37
np.random.seed(random_seed)
from tensorflow import set_random_seed
set_random_seed(random_seed)
###########################################################

# For each recording
#     Resample feature dataframe
#     Add first derivatives of selected features
#     Annotate frames
#     Save as new annotated dataframe, 0 => not a nod, 1 => nod

import os
import glob
import pandas as pd
import scipy.signal
import time
import pympi    # Import pympi to work with elan files

# Unified frame rate
FRAME_RATE = 30

eaf_nod_tier_name = 'Head Nods'

# Features whose first and second derivatives will be calculated
diff_selected_features = [
    ' pose_Tx', 
    ' pose_Ty', 
    ' pose_Tz', 

    ' pose_Rx', 
    ' pose_Ry', 
    ' pose_Rz',

    ' p_rx', 
    ' p_ry',
    ' p_rz'
    
    # add landmarks?
]

input_features_dir = '/home/ICT2000/jondras/datasets/vra1/listener_features'
input_annotations_dir = '/home/ICT2000/jondras/datasets/vra1/listener_nod_annotations'
output_dir = '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
start_time = time.time()    
cnt = 0
for feature_file in sorted(glob.glob(input_features_dir + '/*.csv')):
    
    sid = feature_file.split('/')[-1].split('.')[0][3:]
    print(f'Processing SESID {sid}')
    
    org_df = pd.read_csv(feature_file)
#     print(org_df)
    
    # Resample feature dataframe to common frame rate, if needed
    csv_frame_rate = (org_df.shape[0] - 1) / np.sum(np.diff(org_df[' timestamp']))
    print(f'\tcsv frame rate: {csv_frame_rate}')
    if round(csv_frame_rate) == 30:
        print(f'\tNOT resampling')
        new_df = org_df.copy()
    else:
        print(f'\tREsampling')
        n_resampled_points = int(1 + (len(org_df[' timestamp']) - 1) * FRAME_RATE / csv_frame_rate)
        new_df = []
        for col_name in org_df.columns:            
            new_col = scipy.signal.resample(org_df[col_name], num=n_resampled_points)
            new_df.append(new_col)
        new_df = pd.DataFrame(np.array(new_df).T, columns=org_df.columns) 
        
    # Add first and second derivatives of selected features
    diff_features = dict()
    for feature_name in diff_selected_features:
        diff_features['diff_' + feature_name] =  np.diff(new_df[feature_name], prepend=new_df[feature_name][0])
        diff_features['diff2_' + feature_name] = np.diff(diff_features['diff_' + feature_name], 
                                                         prepend=diff_features['diff_' + feature_name][0])    
    new_df = new_df.assign(**diff_features)
            
    # Annotate frames
    # Add annotation column
    new_df = new_df.assign(nod=np.zeros(len(new_df), dtype=int))
    eaf_obj = pympi.Elan.Eaf(f'{input_annotations_dir}/SES{sid}.eaf')
    # Ignore annotations other than head nods (e.g. the default tier name)
    if eaf_nod_tier_name in eaf_obj.get_tier_names():
        anns = eaf_obj.get_annotation_data_for_tier(eaf_nod_tier_name)
        # Iterate over annotation intervals (in milliseconds)
        for ann in anns:
            interval_begin = ann[0] / 1000.
            interval_end   = ann[1] / 1000.
            new_df.nod = pd.np.where((new_df[' timestamp'] >= interval_begin) & (new_df[' timestamp'] <= interval_end), 
                                     1, new_df.nod)
#             print(interval_begin, interval_end)
#             print(np.where(np.array(new_df.nod) == 1))
    
    # Save as new annotated dataframe
#     print(new_df)
    new_df.to_csv(f'{output_dir}/SES{sid}.csv', index=False)
    cnt += 1
    print(f'Time taken: {time.time() - start_time} s\n')        
#     break

print(f'\nGenerated {cnt} annotated feature sets.')
# Out:
# Processing SESID 101
# 	csv frame rate: 29.970015322243647
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 4.662138223648071 s
#
# Processing SESID 102
# 	csv frame rate: 29.969987541998563
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 11.702477931976318 s
#
# Processing SESID 104
# 	csv frame rate: 29.970003273584844
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 16.734755992889404 s
#
# Processing SESID 106
# 	csv frame rate: 29.9699495027727
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 22.039222240447998 s
#
# Processing SESID 109
# 	csv frame rate: 29.969950130002985
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 28.271963834762573 s
#
# Processing SESID 110
# 	csv frame rate: 29.970148243989478
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 32.23234009742737 s
#
# Processing SESID 112
# 	csv frame rate: 29.97004500775217
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 36.62758255004883 s
#
# Processing SESID 114
# 	csv frame rate: 29.970071495870975
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 39.055970668792725 s
#
# Processing SESID 130
# 	csv frame rate: 29.970131856924308
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 43.56829595565796 s
#
# Processing SESID 138
# 	csv frame rate: 29.970043480906945
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 48.402108669281006 s
#
# Processing SESID 141
# 	csv frame rate: 29.970079636978312
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 55.64687752723694 s
#
# Processing SESID 142
# 	csv frame rate: 29.970024651130597
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 61.856576919555664 s
#
# Processing SESID 143
# 	csv frame rate: 29.97002196251944
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 66.02366590499878 s
#
# Processing SESID 144
# 	csv frame rate: 29.969911196875888
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 69.65165328979492 s
#
# Processing SESID 146
# 	csv frame rate: 29.970070266302024
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 73.82301211357117 s
#
# Processing SESID 147
# 	csv frame rate: 29.9699920917787
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 79.92322373390198 s
#
# Processing SESID 148
# 	csv frame rate: 29.969908755581443
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 82.74021315574646 s
#
# Processing SESID 149
# 	csv frame rate: 29.97016161673209
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 86.42542576789856 s
#
# Processing SESID 150
# 	csv frame rate: 29.970089140284898
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 90.93663716316223 s
#
# Processing SESID 153
# 	csv frame rate: 29.969972558654078
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 93.33269357681274 s
#
# Processing SESID 154
# 	csv frame rate: 29.969960342075733
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 98.14777779579163 s
#
# Processing SESID 155
# 	csv frame rate: 29.970058030121734
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 104.08359742164612 s
#
# Processing SESID 156
# 	csv frame rate: 29.97007059435896
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 108.12974214553833 s
#
# Processing SESID 157
# 	csv frame rate: 29.970078495375766
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 111.59219360351562 s
#
# Processing SESID 158
# 	csv frame rate: 29.97012558193589
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 116.41477656364441 s
#
# Processing SESID 159
# 	csv frame rate: 29.969981601626802
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 121.20046353340149 s
#
# Processing SESID 160
# 	csv frame rate: 29.970017592982632
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 123.91141414642334 s
#
# Processing SESID 161
# 	csv frame rate: 29.970104633781762
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 128.70684003829956 s
#
# Processing SESID 162
# 	csv frame rate: 29.97010840609946
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 134.5726592540741 s
#
# Processing SESID 163
# 	csv frame rate: 29.969931483215852
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 138.00921654701233 s
#
# Processing SESID 164
# 	csv frame rate: 29.97008879154008
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 140.87326312065125 s
#
# Processing SESID 28
# 	csv frame rate: 29.96994749067051
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 146.82344770431519 s
#
# Processing SESID 38
# 	csv frame rate: 29.96992637146116
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 151.23319029808044 s
#
# Processing SESID 39
# 	csv frame rate: 29.970070307019096
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 157.72271156311035 s
#
# Processing SESID 53
# 	csv frame rate: 29.970045121904977
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 162.19008445739746 s
#
# Processing SESID 56
# 	csv frame rate: 29.970115269674118
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 166.8580470085144 s
#
# Processing SESID 6
# 	csv frame rate: 29.999959261326367
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 175.1169137954712 s
#
# Processing SESID 60
# 	csv frame rate: 29.969971720941082
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 178.73055624961853 s
#
# Processing SESID 69
# 	csv frame rate: 29.969983530786802
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 183.74195790290833 s
#
# Processing SESID 83
# 	csv frame rate: 29.969990883801724
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 192.1167709827423 s
#
# Processing SESID 9
# 	csv frame rate: 30.000057859320847
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 197.88796973228455 s
#
# Processing SESID 95
# 	csv frame rate: 29.969945154151358
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 203.77971625328064 s
#
# Processing SESID 96
# 	csv frame rate: 29.97007837769083
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 206.58237648010254 s
#
# Processing SESID 97
# 	csv frame rate: 29.97015918182574
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 210.2481496334076 s
#
# Processing SESID 98
# 	csv frame rate: 29.970157737672302
# 	NOT resampling
# Parsing unknown version of ELAN spec... This could result in errors...
# Time taken: 212.5937044620514 s
#
#
# Generated 45 annotated feature sets.
