# %%
# Show training history of all models

from utils import load_train_history, plot_loss_history
import glob

for hist_filename in sorted(glob.glob('./model_checkpoints/*.pkl')):
    h = load_train_history(hist_filename)
    plot_loss_history(h)
#     print(h)
# Out:
# Loading: hatice2010_nod_32ws_12f_128u.pkl
# 	Min train loss: 0.13123328400105927 @epoch 25
# 	Min valid loss: 0.3545069185645175 @epoch 15
# Loading: hatice2010_nod_32ws_12f_32-32u.pkl
# 	Min train loss: 0.148191408010315 @epoch 31
# 	Min valid loss: 0.3075712835209674 @epoch 21
# Loading: hatice2010_nod_32ws_12f_64u.pkl
# 	Min train loss: 0.14879778561379892 @epoch 25
# 	Min valid loss: 0.35244979551248845 @epoch 16
# Loading: hatice2010_nod_32ws_6f_128u.pkl
# 	Min train loss: 0.15786075409833367 @epoch 27
# 	Min valid loss: 0.3556193652727032 @epoch 17
# Loading: nvb_nod_32ws_12f_128u.pkl
# 	Min train loss: 0.07022424329005662 @epoch 10
# 	Min valid loss: 0.174804685037834 @epoch 0
# Loading: nvb_nod_32ws_12f_32-32u.pkl
# 	Min train loss: 0.1279699638878902 @epoch 11
# 	Min valid loss: 0.17028263885207218 @epoch 1
# Loading: nvb_nod_32ws_12f_64u.pkl
# 	Min train loss: 0.10672803654395903 @epoch 11
# 	Min valid loss: 0.17555049729105895 @epoch 1
# Loading: nvb_nod_32ws_6f_128u.pkl
# ...

# %%
# Show training history of all models

from utils import load_train_history, plot_loss_history
import glob

for hist_filename in sorted(glob.glob('./model_checkpoints/vra1_nod_32ws_12f_128u.pkl')):
    h = load_train_history(hist_filename)
    plot_loss_history(h)
#     print(h)
# Out:
# Loading: vra1_nod_32ws_12f_128u.pkl
# 	Min train loss: 0.1655549895284101 @epoch 11
# 	Min valid loss: 0.38318550244417193 @epoch 1

# %%
# Show training history of all models

from utils import load_train_history, plot_loss_history
import glob

for hist_filename in sorted(glob.glob('./model_checkpoints/vra1_nod_32ws_12f_16u.pkl')):
    h = load_train_history(hist_filename)
    plot_loss_history(h)
#     print(h)
# Out:
# Loading: vra1_nod_32ws_12f_16u.pkl
# 	Min train loss: 0.30625627730358973 @epoch 27
# 	Min valid loss: 0.3833646557394203 @epoch 17

# %%
# Show training history of all models

from utils import load_train_history, plot_loss_history
import glob

for hist_filename in sorted(glob.glob('./model_checkpoints/vra1_nod_32ws_12f_16u.pkl')):
    h = load_train_history(hist_filename)
    plot_loss_history(h)
#     print(h)
# Out:
# Loading: vra1_nod_32ws_12f_16u.pkl
# 	Min train loss: 30.61688532992769 @epoch 27
# 	Min valid loss: 38.32698510789141 @epoch 17

# %%
from utils import load_train_history, plot_loss_history, plot_custom_metric_history
import glob

for hist_filename in sorted(glob.glob('./model_checkpoints/vra1_nod_32ws_12f_8u.pkl')):
    h = load_train_history(hist_filename)
    plot_custom_metric_history(h, metric_name='bacc')
# Out:
# Loading: vra1_nod_32ws_12f_8u.pkl
# 	[last] Max train bacc: 0.8653 @epoch 2
# 	[last] Max val bacc: 0.8362 @epoch 2
#
# 	[majority] Max train bacc: 0.8612 @epoch 2
# 	[majority] Max val bacc: 0.8308 @epoch 2
