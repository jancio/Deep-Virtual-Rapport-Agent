# %%
###########################################################
import numpy as np
random_seed = 37
np.random.seed(random_seed)
from tensorflow import set_random_seed
set_random_seed(random_seed)
###########################################################

import os
import glob
import time
from collections import defaultdict
from sklearn.model_selection import KFold


def split_dataset(n_folds):
    '''
    Split dataset (csv files of recordings) into train+val/test paritions for each fold.
    '''
    
    input_annotated_features_dir = '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe'
    dataset_split_filename = f'/home/ICT2000/jondras/datasets/vra1/subject_independent/dataset_split_{n_folds}fold'
    input_filenames = np.array(sorted(glob.glob(input_annotated_features_dir + '/*.csv')))
    
    n_subjects = len(input_filenames)
    n_test_subjects = int(n_subjects / n_folds)
    n_trainval_subjects = n_subjects - n_test_subjects
    print(f'{n_folds}-fold dataset: \n\t {n_trainval_subjects} train+val subjects \n\t {n_test_subjects} test subjects')
    
    folds = defaultdict(list)
    # Shuffle filenames
    kf = KFold(n_splits=n_folds, shuffle=True, random_state=random_seed)
    for k, (train_indexes, test_indexes) in enumerate(kf.split(input_filenames)):
        folds[f'{k}_trainval'] = input_filenames[train_indexes]
        folds[f'{k}_test']     = input_filenames[test_indexes]
    
    print(f'{folds}')
    
    # Save the dataset split
    np.savez(dataset_split_filename, **folds)
    
    # Verify
    d = np.load(dataset_split_filename + '.npz')
    trainval_set = []
    test_set = set()
    for k in range(n_folds):
        trainval_set.extend(d[f'{k}_trainval'])
        test_set.update(d[f'{k}_test'])
    assert len(trainval_set) == n_folds * n_trainval_subjects, len(trainval_set)
    assert len(test_set) == n_folds * n_test_subjects, len(test_set)

# %%
split_dataset(n_folds=9)
# Out:
# 9-fold dataset:
# 	 40 train+val subjects
# 	 5 test subjects
# defaultdict(<class 'list'>, {'0_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '0_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv'],
#       dtype='<U83'), '1_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv'],
#       dtype='<U83'), '1_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '2_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '2_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv'],
#       dtype='<U83'), '3_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '3_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv'],
#       dtype='<U83'), '4_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '4_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv'],
#       dtype='<U83'), '5_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '5_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv'],
#       dtype='<U83'), '6_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '6_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv'],
#       dtype='<U83'), '7_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '7_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv'],
#       dtype='<U83'), '8_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '8_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv'],
#       dtype='<U83')})
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-2-c6209ce009d9> in <module>
# ----> 1 split_dataset(n_folds=9)
#
# <ipython-input-1-6971a65a3f92> in split_dataset(n_folds)
#      49         test_set.update(d[f'{k}_test'])
#      50     assert len(trainval_set) == n_folds * n_trainval_subjects, len(trainval_set)
# ---> 51     assert len(test_set) == n_test_subjects, len(test_set)
#      52
#
# AssertionError: 45

# %%
# Leave-one-subject-out (LOSO)
split_dataset(n_folds=45)
# Out:
# 45-fold dataset:
# 	 44 train+val subjects
# 	 1 test subjects
# defaultdict(<class 'list'>, {'0_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '0_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv'],
#       dtype='<U83'), '1_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '1_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv'],
#       dtype='<U83'), '2_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '2_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv'],
#       dtype='<U83'), '3_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '3_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv'],
#       dtype='<U83'), '4_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '4_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv'],
#       dtype='<U83'), '5_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '5_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv'],
#       dtype='<U83'), '6_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv'],
#       dtype='<U83'), '6_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '7_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '7_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv'],
#       dtype='<U83'), '8_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '8_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv'],
#       dtype='<U83'), '9_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '9_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv'],
#       dtype='<U83'), '10_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '10_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv'],
#       dtype='<U83'), '11_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
# ...
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '41_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv'],
#       dtype='<U83'), '42_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '42_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv'],
#       dtype='<U83'), '43_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '43_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv'],
#       dtype='<U83'), '44_trainval': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES101.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES102.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES104.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES106.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES109.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES110.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES112.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES114.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES130.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES138.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES141.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES142.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES143.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES144.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES146.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES148.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES149.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES150.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES153.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES154.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES155.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES156.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES157.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES158.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES159.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES160.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES161.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES162.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES163.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES164.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES28.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES38.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES39.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES53.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES56.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES6.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES60.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES69.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES83.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES9.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES95.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES96.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES97.csv',
#        '/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES98.csv'],
#       dtype='<U83'), '44_test': array(['/home/ICT2000/jondras/datasets/vra1/listener_annotated_features_perframe/SES147.csv'],
#       dtype='<U83')})
