# %%
#######################################################################################################################
# Project: Deep Virtual Rapport Agent (data preprocessing)
#
#     Jan Ondras (jo951030@gmail.com)
#     Institute for Creative Technologies, University of Southern California
#     April-October 2019
#
#######################################################################################################################
# Annotate OpenFace features from the hatice2010 dataset with ground-true head gestures.
#
#     Each frame will be annotated with ground-truth annotations of nod and shake head gestures
#
#     Input features: dvra_datasets/hatice2010/openface_features 
#     Output features: dvra_datasets/hatice2010/annotated_features
#######################################################################################################################

# %%
###########################################################
import numpy as np
random_seed = 37
np.random.seed(random_seed)
from tensorflow import set_random_seed
set_random_seed(random_seed)
###########################################################

# For each recording
#     Resample feature dataframe
#     Add first derivatives of selected features
#     Annotate frames
#     Save as new annotated dataframe, 0 => not a nod, 1 => nod
#     Add subject ID and head gesture class into the new filename

import os
import glob
import pandas as pd
import scipy.signal
from scipy import interpolate
import time
import pympi    # Import pympi to work with elan files

# Unified frame rate
FRAME_RATE = 30.

# Features whose first and second derivatives will be calculated
diff_selected_features = [
    ' pose_Tx', 
    ' pose_Ty', 
    ' pose_Tz', 

    ' pose_Rx', 
    ' pose_Ry', 
    ' pose_Rz',

    ' p_rx', 
    ' p_ry',
    ' p_rz'
    
    # add landmarks?
]

# Map session id prefix to subject ID
sessid_prefix_to_sid = {
    # Classes nod and shake
    '2008.12.05.16.03.15_Operator': 1, 
    '2008.12.05.16.03.15_User': 2, 
    
    '2008.12.14.14.47.07_Operator': 1, 
    '2008.12.14.14.47.07_User': 2, 
    
    '2008.12.19.11.03.11_Operator': 1, 
    '2008.12.19.11.03.11_User': 3,
    
    '2009.01.06.12.41.42_Operator': 1, 
    
    '2009.01.06.14.53.49_Operator': 1, 
    '2009.01.06.14.53.49_User': 4, 
    
    '2009.01.28.15.35.20_Operator': 5, 
    '2009.01.28.15.35.20_User': 1, 
    
    '2009.01.30.12.00.35_Operator': 5, 
    '2009.01.30.12.00.35_User': 2, 
    
    '2009.05.22.15.17.45_User': 6,
    
    '2009.05.25.11.23.09_User': 7, 
    
    '2009.05.26.10.19.53_User': 8, 
    
    # Class other
    '2008': 9, 
    'Alex': 10, 
    'Alis': 11, 
    'anto': 12, 
    'Liam': 13, 
    'maja': 14, 
    'rodA': 15
}

input_features_dir = '/home/ICT2000/jondras/dvra_datasets/hatice2010/openface_features'
output_dir = '/home/ICT2000/jondras/dvra_datasets/hatice2010/annotated_features'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
start_time = time.time()    
cnt = 0
for feature_file in sorted(glob.glob(input_features_dir + '/*/*.csv')):
    
    head_gesture = feature_file.split('/')[-2]
    sessid = feature_file.split('/')[-1][:-4]
    if head_gesture == 'other':
        sessid_prefix = sessid[:4]
    else:
        sessid_prefix = '_'.join(sessid.split('_')[:2])
    sid = sessid_prefix_to_sid[sessid_prefix]
    
    print(f'Processing SESSID {sid}\n\t head gesture: {head_gesture}\t sessid_prefix: {sessid_prefix}\t sid: {sid}')
   
    org_df = pd.read_csv(feature_file)
    print(f'\t original dataframe length {len(org_df)}')
#     print(len(org_df), org_df)
    
    # Resample feature dataframe to common frame rate, if needed
    csv_frame_rate = (org_df.shape[0] - 1) / np.sum(np.diff(org_df[' timestamp']))
    print(f'\tcsv frame rate: {csv_frame_rate}')
    if round(csv_frame_rate) == FRAME_RATE:
        print(f'\tNOT resampling')
        new_df = org_df.copy()
    else:
        print(f'\tREsampling from {csv_frame_rate} to {FRAME_RATE}')
        new_df = []
        timestamps_resampled = np.arange(0., org_df.iloc[-1][' timestamp'], step=1. / FRAME_RATE)
        for col_name in org_df.columns:            
            # Get interpolation function
            f = interpolate.interp1d(x=org_df[' timestamp'], y=org_df[col_name], kind='linear')
            new_df.append( f(timestamps_resampled) )
        # This approach does not work properly
#         n_resampled_points = int(1 + (len(org_df[' timestamp']) - 1) * FRAME_RATE / csv_frame_rate)
#         for col_name in org_df.columns:            
#             new_col = scipy.signal.resample(np.array(org_df[col_name]), num=n_resampled_points)
#             new_df.append(new_col)
        new_df = pd.DataFrame(np.array(new_df).T, columns=org_df.columns) 
                
    # Add first and second derivatives of selected features
    diff_features = dict()
    for feature_name in diff_selected_features:
        diff_features['diff_' + feature_name] =  np.diff(new_df[feature_name], prepend=new_df[feature_name][0])
        diff_features['diff2_' + feature_name] = np.diff(diff_features['diff_' + feature_name], 
                                                         prepend=diff_features['diff_' + feature_name][0])    
    new_df = new_df.assign(**diff_features)
            
    # Annotate frames
    # Add annotation columns for nod and shake
    new_df = new_df.assign(nod=(1 if head_gesture == 'nod' else 0))
    new_df = new_df.assign(shake=(1 if head_gesture == 'shake' else 0))
#     print(new_df)
#     print(np.where(np.array(new_df.nod) == 1))
#     print(np.where(np.array(new_df.shake) == 1))
    
    # Save as new annotated dataframe
#     print(new_df)
    new_df.to_csv(f'{output_dir}/{sid}_{head_gesture}_{sessid}.csv', index=False)
    cnt += 1
    print(f'Time taken: {time.time() - start_time} s\n')        
#     break

print(f'\nGenerated {cnt} annotated feature files.')
# Out:
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 80
# 	csv frame rate: 49.968374446552815
# 	REsampling from 49.968374446552815 to 30.0
# Time taken: 0.4323842525482178 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 0.8656871318817139 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 1.2725677490234375 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 148
# 	csv frame rate: 49.98299897993879
# 	REsampling from 49.98299897993879 to 30.0
# Time taken: 1.7885921001434326 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 2.1822073459625244 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 2.60878849029541 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 2.9938693046569824 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 3.40694260597229 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 3.8684375286102295 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 65
# 	csv frame rate: 49.960967993754885
# 	REsampling from 49.960967993754885 to 30.0
# Time taken: 4.315237045288086 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 4.719043016433716 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 85
# 	csv frame rate: 49.97025580011898
# 	REsampling from 49.97025580011898 to 30.0
# Time taken: 5.200360298156738 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 114
# 	csv frame rate: 49.97788589119858
# 	REsampling from 49.97788589119858 to 30.0
# Time taken: 5.68450927734375 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 6.091256856918335 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 6.53596043586731 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 125
# 	csv frame rate: 49.979846835953246
# 	REsampling from 49.979846835953246 to 30.0
# Time taken: 7.013628959655762 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 130
# 	csv frame rate: 49.98062766369623
# 	REsampling from 49.98062766369623 to 30.0
# Time taken: 7.534818172454834 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 90
# 	csv frame rate: 49.971925884334645
# 	REsampling from 49.971925884334645 to 30.0
# Time taken: 7.9872846603393555 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 80
# 	csv frame rate: 49.968374446552815
# 	REsampling from 49.968374446552815 to 30.0
# Time taken: 8.424248933792114 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 8.854441404342651 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 80
# 	csv frame rate: 49.968374446552815
# 	REsampling from 49.968374446552815 to 30.0
# Time taken: 9.362424850463867 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 9.807339429855347 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 80
# 	csv frame rate: 49.968374446552815
# 	REsampling from 49.968374446552815 to 30.0
# Time taken: 10.251315116882324 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 10.672282218933105 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 72
# 	csv frame rate: 49.96481351161154
# 	REsampling from 49.96481351161154 to 30.0
# Time taken: 11.293415784835815 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 37
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 11.753889560699463 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 12.174649000167847 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 68
# 	csv frame rate: 49.96271439224459
# 	REsampling from 49.96271439224459 to 30.0
# Time taken: 12.627688646316528 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 78
# 	csv frame rate: 49.967553536664504
# 	REsampling from 49.967553536664504 to 30.0
# Time taken: 13.057119369506836 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 13.488301038742065 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 13.872941970825195 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 14.25575304031372 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 25
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 14.757199764251709 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 15.168143510818481 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 90
# 	csv frame rate: 49.971925884334645
# 	REsampling from 49.971925884334645 to 30.0
# Time taken: 15.596782684326172 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 16.009250164031982 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 115
# 	csv frame rate: 49.978079789565975
# 	REsampling from 49.978079789565975 to 30.0
# Time taken: 16.470151662826538 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 65
# 	csv frame rate: 49.960967993754885
# 	REsampling from 49.960967993754885 to 30.0
# Time taken: 16.897766590118408 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 28
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 17.29212784767151 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 17.709778308868408 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 18.119755029678345 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 18.583054304122925 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 94
# 	csv frame rate: 49.97313272434175
# 	REsampling from 49.97313272434175 to 30.0
# Time taken: 19.053597927093506 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 19.490318775177002 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 19.959654569625854 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 25
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 20.368327617645264 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 170
# 	csv frame rate: 49.9852114758947
# 	REsampling from 49.9852114758947 to 30.0
# Time taken: 20.932327032089233 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 21.36098074913025 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 21.802099227905273 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 25
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 22.21271800994873 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 22
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 22.623055458068848 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 23.094791173934937 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 23.57261824607849 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 23.973533391952515 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 32
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 24.433062314987183 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 45
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 24.87471318244934 s
#
# Processing SESSID 2
# 	 head gesture: nod	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 91
# 	csv frame rate: 49.972237645752365
# 	REsampling from 49.972237645752365 to 30.0
# Time taken: 25.388611555099487 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 91
# 	csv frame rate: 49.972237645752365
# 	REsampling from 49.972237645752365 to 30.0
# Time taken: 25.898875951766968 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 48
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 26.332724571228027 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 52
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 26.802374124526978 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 64
# 	csv frame rate: 49.9603489294211
# 	REsampling from 49.9603489294211 to 30.0
# Time taken: 27.257474899291992 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 27.666341304779053 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 61
# 	csv frame rate: 49.95836802664447
# 	REsampling from 49.95836802664447 to 30.0
# Time taken: 28.100396633148193 s
#
# Processing SESSID 3
# 	 head gesture: nod	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 58
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 28.574017763137817 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 28.985393047332764 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 44
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 29.394158363342285 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 75
# 	csv frame rate: 49.966239027684004
# 	REsampling from 49.966239027684004 to 30.0
# Time taken: 29.82826542854309 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 56
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 30.263201475143433 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 43
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 30.7361843585968 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 53
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 31.16307258605957 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 44
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 31.579209089279175 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 47
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 31.99908995628357 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 71
# 	csv frame rate: 49.964311206281224
# 	REsampling from 49.964311206281224 to 30.0
# Time taken: 32.44000267982483 s
#
# Processing SESSID 4
# 	 head gesture: nod	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 48
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 32.846656799316406 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 44
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 33.25810503959656 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 85
# 	csv frame rate: 49.97025580011898
# 	REsampling from 49.97025580011898 to 30.0
# Time taken: 33.708914041519165 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 34.1169707775116 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 52
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 34.526339530944824 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 68
# 	csv frame rate: 49.96271439224459
# 	REsampling from 49.96271439224459 to 30.0
# Time taken: 34.95295834541321 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 53
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 35.36189937591553 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 61
# 	csv frame rate: 49.95836802664447
# 	REsampling from 49.95836802664447 to 30.0
# Time taken: 35.84577703475952 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 85
# 	csv frame rate: 49.97025580011898
# 	REsampling from 49.97025580011898 to 30.0
# Time taken: 36.281503677368164 s
#
# Processing SESSID 5
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 160
# 	csv frame rate: 49.98428167243005
# 	REsampling from 49.98428167243005 to 30.0
# Time taken: 36.799604654312134 s
#
# Processing SESSID 1
# 	 head gesture: nod	 sessid_prefix: 2009.01.28.15.35.20_User	 sid: 1
# 	 original dataframe length 20
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 37.17602729797363 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 37.591814041137695 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 31
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 37.98220896720886 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 45
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 38.39779043197632 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 84
# 	csv frame rate: 49.969897652016854
# 	REsampling from 49.969897652016854 to 30.0
# Time taken: 38.8234601020813 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 43
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 39.21781325340271 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 31
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 39.59737682342529 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 66
# 	csv frame rate: 49.96156802459647
# 	REsampling from 49.96156802459647 to 30.0
# Time taken: 40.03402781486511 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 265
# 	csv frame rate: 49.98106777735706
# 	REsampling from 49.98106777735706 to 30.0
# Time taken: 40.65820288658142 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 66
# 	csv frame rate: 49.96156802459647
# 	REsampling from 49.96156802459647 to 30.0
# Time taken: 41.13812470436096 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 54
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 41.548476696014404 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 76
# 	csv frame rate: 49.96668887408395
# 	REsampling from 49.96668887408395 to 30.0
# Time taken: 41.991557121276855 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 42.402116775512695 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 132
# 	csv frame rate: 49.98092331171308
# 	REsampling from 49.98092331171308 to 30.0
# Time taken: 42.88861584663391 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 43.290629148483276 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 107
# 	csv frame rate: 49.97642621404998
# 	REsampling from 49.97642621404998 to 30.0
# Time taken: 43.75016498565674 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 76
# 	csv frame rate: 49.96668887408395
# 	REsampling from 49.96668887408395 to 30.0
# Time taken: 44.180139780044556 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 72
# 	csv frame rate: 49.96481351161154
# 	REsampling from 49.96481351161154 to 30.0
# Time taken: 44.61079287528992 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 71
# 	csv frame rate: 49.964311206281224
# 	REsampling from 49.964311206281224 to 30.0
# Time taken: 45.02711844444275 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 131
# 	csv frame rate: 49.98077662437523
# 	REsampling from 49.98077662437523 to 30.0
# Time taken: 45.506370544433594 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 113
# 	csv frame rate: 49.9776885319054
# 	REsampling from 49.9776885319054 to 30.0
# Time taken: 45.97678589820862 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 69
# 	csv frame rate: 49.96326230712711
# 	REsampling from 49.96326230712711 to 30.0
# Time taken: 46.462703466415405 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 48
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 46.87527537345886 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 32
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 47.27227187156677 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 47.685574531555176 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 48.10367941856384 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 48.49928689002991 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 48.899235010147095 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 80
# 	csv frame rate: 49.968374446552815
# 	REsampling from 49.968374446552815 to 30.0
# Time taken: 49.33380651473999 s
#
# Processing SESSID 6
# 	 head gesture: nod	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 27
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 49.726773262023926 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 73
# 	csv frame rate: 49.96530187369883
# 	REsampling from 49.96530187369883 to 30.0
# Time taken: 50.16223073005676 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 50.58591270446777 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 51.00170683860779 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 94
# 	csv frame rate: 49.97313272434175
# 	REsampling from 49.97313272434175 to 30.0
# Time taken: 51.5060293674469 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 79
# 	csv frame rate: 49.967969250480465
# 	REsampling from 49.967969250480465 to 30.0
# Time taken: 51.93440103530884 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 85
# 	csv frame rate: 49.97025580011898
# 	REsampling from 49.97025580011898 to 30.0
# Time taken: 52.37154984474182 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 108
# 	csv frame rate: 49.976646426903315
# 	REsampling from 49.976646426903315 to 30.0
# Time taken: 52.85029196739197 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 51
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 53.26323914527893 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 52
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 53.67690634727478 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 73
# 	csv frame rate: 49.96530187369883
# 	REsampling from 49.96530187369883 to 30.0
# Time taken: 54.10020995140076 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 97
# 	csv frame rate: 49.97397188964081
# 	REsampling from 49.97397188964081 to 30.0
# Time taken: 54.553526639938354 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 64
# 	csv frame rate: 49.9603489294211
# 	REsampling from 49.9603489294211 to 30.0
# Time taken: 54.98101806640625 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 93
# 	csv frame rate: 49.97284084736556
# 	REsampling from 49.97284084736556 to 30.0
# Time taken: 55.43427658081055 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 83
# 	csv frame rate: 49.96953077391834
# 	REsampling from 49.96953077391834 to 30.0
# Time taken: 55.86394953727722 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 59
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 56.29066491127014 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 53
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 56.77555251121521 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 51
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 57.19150114059448 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 34
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 57.57954168319702 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 67
# 	csv frame rate: 49.96214988644966
# 	REsampling from 49.96214988644966 to 30.0
# Time taken: 58.00194597244263 s
#
# Processing SESSID 7
# 	 head gesture: nod	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 82
# 	csv frame rate: 49.9691548426897
# 	REsampling from 49.9691548426897 to 30.0
# Time taken: 58.4509642124176 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 88
# 	csv frame rate: 49.97128087306146
# 	REsampling from 49.97128087306146 to 30.0
# Time taken: 58.88761758804321 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 52
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 59.29410243034363 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 59.713488817214966 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 66
# 	csv frame rate: 49.96156802459647
# 	REsampling from 49.96156802459647 to 30.0
# Time taken: 60.14540910720825 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 47
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 60.56243681907654 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 60.98439025878906 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 78
# 	csv frame rate: 49.967553536664504
# 	REsampling from 49.967553536664504 to 30.0
# Time taken: 61.41726016998291 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 37
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 61.87265706062317 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 83
# 	csv frame rate: 49.96953077391834
# 	REsampling from 49.96953077391834 to 30.0
# Time taken: 62.31166696548462 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 62
# 	csv frame rate: 49.95904995904996
# 	REsampling from 49.95904995904996 to 30.0
# Time taken: 62.726964473724365 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 63.13691711425781 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 67
# 	csv frame rate: 49.96214988644966
# 	REsampling from 49.96214988644966 to 30.0
# Time taken: 63.554943323135376 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 63.972169399261475 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 76
# 	csv frame rate: 49.96668887408395
# 	REsampling from 49.96668887408395 to 30.0
# Time taken: 64.4032666683197 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 64.81900787353516 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 99
# 	csv frame rate: 49.97450280469149
# 	REsampling from 49.97450280469149 to 30.0
# Time taken: 65.2705545425415 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 56
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 65.6841492652893 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 66.0804750919342 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 68
# 	csv frame rate: 49.96271439224459
# 	REsampling from 49.96271439224459 to 30.0
# Time taken: 66.49959707260132 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 105
# 	csv frame rate: 49.975973089860645
# 	REsampling from 49.975973089860645 to 30.0
# Time taken: 67.00618481636047 s
#
# Processing SESSID 8
# 	 head gesture: nod	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 67.4229416847229 s
#
# Processing SESSID 9
# 	 head gesture: other	 sessid_prefix: 2008	 sid: 9
# 	 original dataframe length 2085
# 	csv frame rate: 60.99988291769113
# 	REsampling from 60.99988291769113 to 30.0
# Time taken: 69.68669104576111 s
#
# Processing SESSID 10
# 	 head gesture: other	 sessid_prefix: Alex	 sid: 10
# 	 original dataframe length 84
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 70.17774677276611 s
#
# Processing SESSID 10
# 	 head gesture: other	 sessid_prefix: Alex	 sid: 10
# 	 original dataframe length 114
# 	csv frame rate: 25.000000000000004
# 	REsampling from 25.000000000000004 to 30.0
# Time taken: 70.7147126197815 s
#
# Processing SESSID 10
# 	 head gesture: other	 sessid_prefix: Alex	 sid: 10
# 	 original dataframe length 67
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 71.19210958480835 s
#
# Processing SESSID 10
# 	 head gesture: other	 sessid_prefix: Alex	 sid: 10
# 	 original dataframe length 107
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 71.72527074813843 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 150
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 72.3401517868042 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 93
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 72.8536868095398 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 186
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 73.54088306427002 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 104
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 74.08100652694702 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 187
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 74.77206635475159 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 197
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 75.5161554813385 s
#
# Processing SESSID 11
# 	 head gesture: other	 sessid_prefix: Alis	 sid: 11
# 	 original dataframe length 119
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 76.07295846939087 s
#
# Processing SESSID 13
# 	 head gesture: other	 sessid_prefix: Liam	 sid: 13
# 	 original dataframe length 47
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 76.49679207801819 s
#
# Processing SESSID 13
# 	 head gesture: other	 sessid_prefix: Liam	 sid: 13
# 	 original dataframe length 62
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 76.94628739356995 s
#
# Processing SESSID 12
# 	 head gesture: other	 sessid_prefix: anto	 sid: 12
# 	 original dataframe length 145
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 77.55437588691711 s
#
# Processing SESSID 12
# 	 head gesture: other	 sessid_prefix: anto	 sid: 12
# 	 original dataframe length 140
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 78.15387392044067 s
#
# Processing SESSID 14
# 	 head gesture: other	 sessid_prefix: maja	 sid: 14
# 	 original dataframe length 55
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 78.63004875183105 s
#
# Processing SESSID 14
# 	 head gesture: other	 sessid_prefix: maja	 sid: 14
# 	 original dataframe length 70
# 	csv frame rate: 25.000000000000004
# 	REsampling from 25.000000000000004 to 30.0
# Time taken: 79.10011315345764 s
#
# Processing SESSID 14
# 	 head gesture: other	 sessid_prefix: maja	 sid: 14
# 	 original dataframe length 125
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 79.66455316543579 s
#
# Processing SESSID 14
# 	 head gesture: other	 sessid_prefix: maja	 sid: 14
# 	 original dataframe length 100
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 80.17636013031006 s
#
# Processing SESSID 14
# 	 head gesture: other	 sessid_prefix: maja	 sid: 14
# 	 original dataframe length 83
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 80.67002296447754 s
#
# Processing SESSID 15
# 	 head gesture: other	 sessid_prefix: rodA	 sid: 15
# 	 original dataframe length 70
# 	csv frame rate: 25.000000000000004
# 	REsampling from 25.000000000000004 to 30.0
# Time taken: 81.16875767707825 s
#
# Processing SESSID 15
# 	 head gesture: other	 sessid_prefix: rodA	 sid: 15
# 	 original dataframe length 180
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 81.91779351234436 s
#
# Processing SESSID 15
# 	 head gesture: other	 sessid_prefix: rodA	 sid: 15
# 	 original dataframe length 92
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 82.41874146461487 s
#
# Processing SESSID 15
# 	 head gesture: other	 sessid_prefix: rodA	 sid: 15
# 	 original dataframe length 128
# 	csv frame rate: 25.0
# 	REsampling from 25.0 to 30.0
# Time taken: 83.00803875923157 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 140
# 	csv frame rate: 49.982020855807264
# 	REsampling from 49.982020855807264 to 30.0
# Time taken: 83.5047869682312 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 80
# 	csv frame rate: 49.968374446552815
# 	REsampling from 49.968374446552815 to 30.0
# Time taken: 83.9593997001648 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 66
# 	csv frame rate: 49.96156802459647
# 	REsampling from 49.96156802459647 to 30.0
# Time taken: 84.42446947097778 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 75
# 	csv frame rate: 49.966239027684004
# 	REsampling from 49.966239027684004 to 30.0
# Time taken: 84.86886191368103 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 75
# 	csv frame rate: 49.966239027684004
# 	REsampling from 49.966239027684004 to 30.0
# Time taken: 85.32461094856262 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_Operator	 sid: 1
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 85.75732469558716 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 36
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 86.17460012435913 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 122
# 	csv frame rate: 49.979347377116895
# 	REsampling from 49.979347377116895 to 30.0
# Time taken: 86.64271807670593 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 73
# 	csv frame rate: 49.96530187369883
# 	REsampling from 49.96530187369883 to 30.0
# Time taken: 87.07816481590271 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 87.54143953323364 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 87.97019863128662 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 45
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 88.37626242637634 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 88.76876449584961 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 110
# 	csv frame rate: 49.97707473635947
# 	REsampling from 49.97707473635947 to 30.0
# Time taken: 89.23560738563538 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.05.16.03.15_User	 sid: 2
# 	 original dataframe length 73
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 89.66095185279846 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 90.07510709762573 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 25
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 90.47209620475769 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 62
# 	csv frame rate: 49.95904995904996
# 	REsampling from 49.95904995904996 to 30.0
# Time taken: 90.89460158348083 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 39
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 91.29550385475159 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 44
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 91.71464896202087 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_Operator	 sid: 1
# 	 original dataframe length 92
# 	csv frame rate: 49.9725425590335
# 	REsampling from 49.9725425590335 to 30.0
# Time taken: 92.1718156337738 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 20
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 92.61612868309021 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 93.00826287269592 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 93.40116238594055 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 93.80570197105408 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 94.19106364250183 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 94.61120581626892 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 19
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 95.0005693435669 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 95.41606736183167 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 30
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 95.81992769241333 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2008.12.14.14.47.07_User	 sid: 2
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 96.2324812412262 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_Operator	 sid: 1
# 	 original dataframe length 66
# 	csv frame rate: 49.96156802459647
# 	REsampling from 49.96156802459647 to 30.0
# Time taken: 96.64963984489441 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_Operator	 sid: 1
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 97.04486322402954 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_Operator	 sid: 1
# 	 original dataframe length 29
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 97.51609754562378 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_Operator	 sid: 1
# 	 original dataframe length 63
# 	csv frame rate: 49.95970991136181
# 	REsampling from 49.95970991136181 to 30.0
# Time taken: 97.9341459274292 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_Operator	 sid: 1
# 	 original dataframe length 20
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 98.3053789138794 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_Operator	 sid: 1
# 	 original dataframe length 54
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 98.70881986618042 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 24
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 99.09418797492981 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 20
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 99.47310280799866 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 59
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 99.88896799087524 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 78
# 	csv frame rate: 49.967553536664504
# 	REsampling from 49.967553536664504 to 30.0
# Time taken: 100.32209062576294 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 74
# 	csv frame rate: 49.965776865160855
# 	REsampling from 49.965776865160855 to 30.0
# Time taken: 100.75514459609985 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 32
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 101.14413642883301 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 24
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 101.52097702026367 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 71
# 	csv frame rate: 49.964311206281224
# 	REsampling from 49.964311206281224 to 30.0
# Time taken: 101.9618968963623 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 102.41535758972168 s
#
# Processing SESSID 3
# 	 head gesture: shake	 sessid_prefix: 2008.12.19.11.03.11_User	 sid: 3
# 	 original dataframe length 170
# 	csv frame rate: 49.9852114758947
# 	REsampling from 49.9852114758947 to 30.0
# Time taken: 102.95738530158997 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.12.41.42_Operator	 sid: 1
# 	 original dataframe length 37
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 103.34672284126282 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.12.41.42_Operator	 sid: 1
# 	 original dataframe length 27
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 103.73471260070801 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.12.41.42_Operator	 sid: 1
# 	 original dataframe length 63
# 	csv frame rate: 49.95970991136181
# 	REsampling from 49.95970991136181 to 30.0
# Time taken: 104.16227388381958 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.12.41.42_Operator	 sid: 1
# 	 original dataframe length 91
# 	csv frame rate: 49.972237645752365
# 	REsampling from 49.972237645752365 to 30.0
# Time taken: 104.60356903076172 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.12.41.42_Operator	 sid: 1
# 	 original dataframe length 85
# 	csv frame rate: 49.97025580011898
# 	REsampling from 49.97025580011898 to 30.0
# Time taken: 105.04131603240967 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 32
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 105.43723106384277 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 60
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 105.8532657623291 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 106.2878806591034 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 34
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 106.67832350730896 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 107.10083222389221 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 36
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 107.55481886863708 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 27
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 107.94640326499939 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 22
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 108.3396315574646 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 31
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 108.75576758384705 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 28
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 109.16022205352783 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 21
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 109.54302453994751 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_Operator	 sid: 1
# 	 original dataframe length 16
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 109.92437148094177 s
#
# Processing SESSID 4
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 25
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 110.33696699142456 s
#
# Processing SESSID 4
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 58
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 110.75913166999817 s
#
# Processing SESSID 4
# 	 head gesture: shake	 sessid_prefix: 2009.01.06.14.53.49_User	 sid: 4
# 	 original dataframe length 65
# 	csv frame rate: 49.960967993754885
# 	REsampling from 49.960967993754885 to 30.0
# Time taken: 111.22312879562378 s
#
# Processing SESSID 5
# 	 head gesture: shake	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 31
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 111.61573839187622 s
#
# Processing SESSID 5
# 	 head gesture: shake	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 100
# 	csv frame rate: 49.97476022211005
# 	REsampling from 49.97476022211005 to 30.0
# Time taken: 112.07769179344177 s
#
# Processing SESSID 5
# 	 head gesture: shake	 sessid_prefix: 2009.01.28.15.35.20_Operator	 sid: 5
# 	 original dataframe length 31
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 112.5440604686737 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.28.15.35.20_User	 sid: 1
# 	 original dataframe length 59
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 112.96355676651001 s
#
# Processing SESSID 1
# 	 head gesture: shake	 sessid_prefix: 2009.01.28.15.35.20_User	 sid: 1
# 	 original dataframe length 42
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 113.37069511413574 s
#
# Processing SESSID 5
# 	 head gesture: shake	 sessid_prefix: 2009.01.30.12.00.35_Operator	 sid: 5
# 	 original dataframe length 36
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 113.79775762557983 s
#
# Processing SESSID 5
# 	 head gesture: shake	 sessid_prefix: 2009.01.30.12.00.35_Operator	 sid: 5
# 	 original dataframe length 24
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 114.19013285636902 s
#
# Processing SESSID 5
# 	 head gesture: shake	 sessid_prefix: 2009.01.30.12.00.35_Operator	 sid: 5
# 	 original dataframe length 40
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 114.58985996246338 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2009.01.30.12.00.35_User	 sid: 2
# 	 original dataframe length 16
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 114.98018026351929 s
#
# Processing SESSID 2
# 	 head gesture: shake	 sessid_prefix: 2009.01.30.12.00.35_User	 sid: 2
# 	 original dataframe length 55
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 115.41683506965637 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 35
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 115.81724095344543 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 116.24754071235657 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 33
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 116.67051267623901 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 75
# 	csv frame rate: 49.966239027684004
# 	REsampling from 49.966239027684004 to 30.0
# Time taken: 117.10719966888428 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 32
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 117.56844520568848 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 71
# 	csv frame rate: 49.964311206281224
# 	REsampling from 49.964311206281224 to 30.0
# Time taken: 118.02752804756165 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 57
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 118.440514087677 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 51
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 118.84706830978394 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 57
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 119.27105832099915 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 37
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 119.66743111610413 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 56
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 120.09976005554199 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 32
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 120.49245476722717 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 70
# 	csv frame rate: 49.9637943519189
# 	REsampling from 49.9637943519189 to 30.0
# Time taken: 120.91745638847351 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 83
# 	csv frame rate: 49.96953077391834
# 	REsampling from 49.96953077391834 to 30.0
# Time taken: 121.35635018348694 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 50
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 121.78268098831177 s
#
# Processing SESSID 6
# 	 head gesture: shake	 sessid_prefix: 2009.05.22.15.17.45_User	 sid: 6
# 	 original dataframe length 43
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 122.19326329231262 s
#
# Processing SESSID 7
# 	 head gesture: shake	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 71
# 	csv frame rate: 49.964311206281224
# 	REsampling from 49.964311206281224 to 30.0
# Time taken: 122.67847776412964 s
#
# Processing SESSID 7
# 	 head gesture: shake	 sessid_prefix: 2009.05.25.11.23.09_User	 sid: 7
# 	 original dataframe length 100
# 	csv frame rate: 49.97476022211005
# 	REsampling from 49.97476022211005 to 30.0
# Time taken: 123.12057662010193 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 100
# 	csv frame rate: 49.97476022211005
# 	REsampling from 49.97476022211005 to 30.0
# Time taken: 123.5767343044281 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 57
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 124.01241970062256 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 90
# 	csv frame rate: 49.971925884334645
# 	REsampling from 49.971925884334645 to 30.0
# Time taken: 124.46853756904602 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 69
# 	csv frame rate: 49.96326230712711
# 	REsampling from 49.96326230712711 to 30.0
# Time taken: 124.89382076263428 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 54
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 125.30742001533508 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 75
# 	csv frame rate: 49.966239027684004
# 	REsampling from 49.966239027684004 to 30.0
# Time taken: 125.74899363517761 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 51
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 126.23528981208801 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 59
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 126.65285968780518 s
#
# Processing SESSID 8
# 	 head gesture: shake	 sessid_prefix: 2009.05.26.10.19.53_User	 sid: 8
# 	 original dataframe length 63
# 	csv frame rate: 49.95970991136181
# 	REsampling from 49.95970991136181 to 30.0
# Time taken: 127.07691192626953 s
#
#
# Generated 283 annotated feature files.
