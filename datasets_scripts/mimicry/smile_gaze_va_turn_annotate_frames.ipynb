# %%
#######################################################################################################################
# Project: Deep Virtual Rapport Agent (head gesture detector)
#
#     Jan Ondras (jo951030@gmail.com)
#     Institute for Creative Technologies, University of Southern California
#     April-October 2019
#
#######################################################################################################################
# Annotate OpenFace vision features from the mimicry dataset with smile, gaze away, voice activity, and take turn 
#     binary labels
# 
#     Run after the vision features are annotated with nod, shake, and tilt head gestures using the developed Head 
#     Gesture Detector (HGD) (deep-virtual-rapport-agent/head_gesture_detector/hgd_annotate_frames.ipynb).
# 
#     Note: it changes the annotated vision featurefiles generated by HGD in-place (!) adding smile, gaze_away, 
#     voice_active and take_turn columns. 
# 
#    Input/output features: dvra_datasets/mimicry/vision_features/annotated_features
#    Input voice activity: dvra_datasets/mimicry/voice_activity_detection/voice_activity_ibm_watson
#######################################################################################################################

###########################################################
import numpy as np
random_seed = 37
np.random.seed(random_seed)
from tensorflow import set_random_seed
set_random_seed(random_seed)
###########################################################

# from utils import SMOOTHING_KERNEL_SIZE
from collections import defaultdict
import pandas as pd
import glob
import time
# from matplotlib import pyplot as plt
import scipy.signal
from scipy import interpolate

# Unified frame rate
FRAME_RATE = 30.

# Based on the fact that smile duration is 500-4000 ms [https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5826373/]
SMILE_SMOOTHING_KERNEL_SIZE = 15
# Based on minimum gaze glance duration ~ 2 s 
GAZE_SMOOTHING_KERNEL_SIZE = 59

DATASET_NAME = 'mimicry'
inputoutput_features_dir = f'/home/ICT2000/jondras/dvra_datasets/{DATASET_NAME}/vision_features/annotated_features'
voice_activity_dir = f'/home/ICT2000/jondras/dvra_datasets/mimicry/voice_activity_detection/voice_activity_ibm_watson'

start_time = time.time()
cnt = 0
for feature_file in sorted(glob.glob(inputoutput_features_dir + '/*.csv')):
    
    file_basename = feature_file.split('/')[-1].split('.')[0]
    print(f'Processing {file_basename}')
    df = pd.read_csv(feature_file)
    print(f'\tDataframe length: {len(df)}')
    
    # Add SMILE annotations & smooth
    smile_ann = np.where((df[' AU06_r'] >= 1.) & (df[' AU12_r'] >= 1.), 1, 0)
    smile_ann = scipy.signal.medfilt(smile_ann, kernel_size=SMILE_SMOOTHING_KERNEL_SIZE).astype(int)
    df['smile'] = smile_ann
    
    # Add GAZE_AWAY annotations & smooth
    gaze_angle_x = df[' gaze_angle_x']
    gaze_angle_y = df[' gaze_angle_y']
    gaze_away_ann = np.where(
        ( (abs(np.mean(gaze_angle_x) - df[' gaze_angle_x']) > np.std(gaze_angle_x)) 
            | (abs(np.mean(gaze_angle_y) - df[' gaze_angle_y']) > np.std(gaze_angle_y)) )
        & (df[' AU45_r'] < 1.), 1, 0)
    gaze_away_ann = scipy.signal.medfilt(gaze_away_ann, kernel_size=GAZE_SMOOTHING_KERNEL_SIZE).astype(int)
    df['gaze_away'] = gaze_away_ann
    
    # Add VOICE_ACTIVE annotations
    va_df = pd.read_csv(f'{voice_activity_dir}/{file_basename}.csv')
    df['voice_active'] = np.zeros(len(df), dtype=int)
    for _, row in va_df.iterrows():
        df['voice_active'] = pd.np.where(
            (df[' timestamp'] >= row['start_time']) & (df[' timestamp'] <= row['end_time']), 1, df['voice_active'])
                
    # Add TAKE_TURN annotations
    take_turn_ann = np.zeros(len(df), dtype=int)
    for j in range(len(df) - 1):
        # End of VA interval => set take_turn in the first frame after the voice active interval
        if (df.iloc[j]['voice_active'] == 1) and (df.iloc[j + 1]['voice_active'] == 0):
            take_turn_ann[j + 1] = 1
    df['take_turn'] = take_turn_ann
    
    # Replace the original dataframe
    df.to_csv(feature_file, index=False)
    cnt += 1
    print(f'\tTime taken: {time.time() - start_time} s\n')        
#     break

print(f'\nGenerated {cnt} fully-annotated feature files.')
# Out:
# Processing sessid_01_P1_sid_09
# 	Dataframe length: 18217
# 	Time taken: 59.08472728729248 s
#
# Processing sessid_01_P2_sid_02
# 	Dataframe length: 18217
# 	Time taken: 117.74326634407043 s
#
# Processing sessid_02_P1_sid_09
# 	Dataframe length: 29598
# 	Time taken: 212.04612016677856 s
#
# Processing sessid_02_P2_sid_17
# 	Dataframe length: 29598
# 	Time taken: 305.9755229949951 s
#
# Processing sessid_03_P1_sid_17
# 	Dataframe length: 13336
# 	Time taken: 349.88799691200256 s
#
# Processing sessid_03_P2_sid_02
# 	Dataframe length: 13336
# 	Time taken: 390.83993434906006 s
#
# Processing sessid_04_P1_sid_12
# 	Dataframe length: 28631
# 	Time taken: 474.8661289215088 s
#
# Processing sessid_04_P2_sid_23
# 	Dataframe length: 28631
# 	Time taken: 568.4601290225983 s
#
# Processing sessid_05_P1_sid_12
# 	Dataframe length: 29297
# 	Time taken: 658.5412974357605 s
#
# Processing sessid_05_P2_sid_21
# 	Dataframe length: 29297
# 	Time taken: 755.7943522930145 s
#
# Processing sessid_06_P1_sid_23
# 	Dataframe length: 29025
# 	Time taken: 845.7748095989227 s
#
# Processing sessid_06_P2_sid_21
# 	Dataframe length: 29025
# 	Time taken: 946.4112000465393 s
#
# Processing sessid_07_P1_sid_09
# 	Dataframe length: 28257
# 	Time taken: 1037.0668976306915 s
#
# Processing sessid_07_P2_sid_01
# 	Dataframe length: 28257
# 	Time taken: 1126.8174140453339 s
#
# Processing sessid_08_P1_sid_09
# 	Dataframe length: 28783
# 	Time taken: 1217.6008515357971 s
#
# Processing sessid_08_P2_sid_04
# 	Dataframe length: 28783
# 	Time taken: 1304.2684013843536 s
#
# Processing sessid_09_P1_sid_01
# 	Dataframe length: 29010
# 	Time taken: 1398.1086075305939 s
#
# Processing sessid_09_P2_sid_04
# 	Dataframe length: 29010
# 	Time taken: 1499.349977016449 s
#
# Processing sessid_10_P1_sid_09
# 	Dataframe length: 29186
# 	Time taken: 1591.5109286308289 s
#
# Processing sessid_10_P2_sid_34
# 	Dataframe length: 29186
# 	Time taken: 1693.458456993103 s
#
# Processing sessid_11_P1_sid_09
# 	Dataframe length: 28143
# 	Time taken: 1797.414321899414 s
#
# Processing sessid_11_P2_sid_15
# 	Dataframe length: 28143
# 	Time taken: 1892.2981071472168 s
#
# Processing sessid_12_P1_sid_15
# 	Dataframe length: 16976
# 	Time taken: 1948.6794185638428 s
#
# Processing sessid_12_P2_sid_11
# 	Dataframe length: 16976
# 	Time taken: 2004.7085409164429 s
#
# Processing sessid_13_P1_sid_09
# 	Dataframe length: 26189
# 	Time taken: 2087.9491415023804 s
#
# Processing sessid_13_P2_sid_19
# 	Dataframe length: 26189
# 	Time taken: 2176.956199645996 s
#
# Processing sessid_14_P1_sid_19
# 	Dataframe length: 20899
# 	Time taken: 2244.25288271904 s
#
# Processing sessid_14_P2_sid_06
# 	Dataframe length: 20899
# 	Time taken: 2312.486235141754 s
#
# Processing sessid_15_P1_sid_09
# 	Dataframe length: 30717
# 	Time taken: 2412.2120735645294 s
#
# Processing sessid_15_P2_sid_16
# 	Dataframe length: 30717
# 	Time taken: 2514.031494617462 s
#
# Processing sessid_16_P1_sid_24
# 	Dataframe length: 32049
# 	Time taken: 2631.455017566681 s
#
# Processing sessid_16_P2_sid_16
# 	Dataframe length: 32049
# 	Time taken: 2733.6434190273285 s
#
# Processing sessid_17_P1_sid_09
# 	Dataframe length: 18566
# 	Time taken: 2795.6156187057495 s
#
# Processing sessid_17_P2_sid_43
# 	Dataframe length: 18566
# 	Time taken: 2855.8749034404755 s
#
# Processing sessid_18_P1_sid_03
# 	Dataframe length: 16958
# 	Time taken: 2914.6904747486115 s
#
# Processing sessid_18_P2_sid_43
# 	Dataframe length: 16958
# 	Time taken: 2970.6279304027557 s
#
# Processing sessid_19_P1_sid_09
# 	Dataframe length: 27220
# 	Time taken: 3056.8419284820557 s
#
# Processing sessid_19_P2_sid_22
# 	Dataframe length: 27220
# 	Time taken: 3154.429763317108 s
#
# Processing sessid_20_P1_sid_09
# 	Dataframe length: 24936
# 	Time taken: 3237.306566953659 s
#
# Processing sessid_20_P2_sid_50
# 	Dataframe length: 24936
# 	Time taken: 3325.419183731079 s
#
# Processing sessid_21_P1_sid_50
# 	Dataframe length: 18101
# 	Time taken: 3386.6536560058594 s
#
# Processing sessid_21_P2_sid_22
# 	Dataframe length: 18101
# 	Time taken: 3448.1540694236755 s
#
# Processing sessid_22_P1_sid_12
# 	Dataframe length: 26418
# 	Time taken: 3534.9924924373627 s
#
# Processing sessid_22_P2_sid_18
# 	Dataframe length: 26418
# 	Time taken: 3628.6034667491913 s
#
# Processing sessid_23_P1_sid_12
# 	Dataframe length: 27446
# 	Time taken: 3716.625970840454 s
#
# Processing sessid_23_P2_sid_39
# 	Dataframe length: 27446
# 	Time taken: 3806.845401287079 s
#
# Processing sessid_24_P1_sid_18
# 	Dataframe length: 13595
# 	Time taken: 3851.8886098861694 s
#
# Processing sessid_24_P2_sid_39
# 	Dataframe length: 13595
# 	Time taken: 3895.270082473755 s
#
# Processing sessid_25_P1_sid_12
# 	Dataframe length: 24458
# 	Time taken: 3972.54719042778 s
#
# Processing sessid_25_P2_sid_27
# 	Dataframe length: 24458
# 	Time taken: 4052.4383795261383 s
#
# Processing sessid_26_P1_sid_12
# 	Dataframe length: 14626
# 	Time taken: 4099.257581710815 s
#
# Processing sessid_26_P2_sid_32
# 	Dataframe length: 14626
# 	Time taken: 4148.416239023209 s
#
# Processing sessid_27_P1_sid_27
# 	Dataframe length: 17224
# 	Time taken: 4204.6380007267 s
#
# Processing sessid_27_P2_sid_32
# 	Dataframe length: 17224
# 	Time taken: 4259.670655488968 s
#
# Processing sessid_28_P1_sid_09
# 	Dataframe length: 28406
# 	Time taken: 4352.691919326782 s
#
# Processing sessid_28_P2_sid_07
# 	Dataframe length: 28406
# 	Time taken: 4446.995169639587 s
#
# Processing sessid_29_P1_sid_09
# 	Dataframe length: 23458
# 	Time taken: 4520.129922628403 s
#
# Processing sessid_29_P2_sid_05
# 	Dataframe length: 23458
# 	Time taken: 4596.537132501602 s
#
# Processing sessid_30_P1_sid_07
# 	Dataframe length: 6601
# 	Time taken: 4618.5640189647675 s
#
# Processing sessid_30_P2_sid_05
# 	Dataframe length: 6601
# 	Time taken: 4640.480452537537 s
#
# Processing sessid_31_P1_sid_28
# 	Dataframe length: 25843
# 	Time taken: 4732.746168136597 s
#
# Processing sessid_31_P2_sid_09
# 	Dataframe length: 25843
# 	Time taken: 4810.897968053818 s
#
# Processing sessid_32_P1_sid_28
# 	Dataframe length: 19064
# 	Time taken: 4873.994483470917 s
#
# Processing sessid_32_P2_sid_14
# 	Dataframe length: 19064
# 	Time taken: 4937.359102964401 s
#
# Processing sessid_33_P1_sid_09
# 	Dataframe length: 28889
# 	Time taken: 5025.482104301453 s
#
# Processing sessid_33_P2_sid_33
# 	Dataframe length: 28889
# 	Time taken: 5127.127879142761 s
#
# Processing sessid_34_P1_sid_09
# 	Dataframe length: 25696
# 	Time taken: 5211.869876623154 s
#
# Processing sessid_34_P2_sid_36
# 	Dataframe length: 25696
# 	Time taken: 5303.073202848434 s
#
# Processing sessid_35_P1_sid_33
# 	Dataframe length: 30039
# 	Time taken: 5418.876909732819 s
#
# Processing sessid_35_P2_sid_36
# 	Dataframe length: 30039
# 	Time taken: 5541.249399662018 s
#
# Processing sessid_36_P1_sid_13
# 	Dataframe length: 27140
# 	Time taken: 5644.501560926437 s
#
# Processing sessid_36_P2_sid_40
# 	Dataframe length: 27140
# 	Time taken: 5753.331650972366 s
#
# Processing sessid_37_P1_sid_13
# 	Dataframe length: 24702
# 	Time taken: 5845.12764954567 s
#
# Processing sessid_37_P2_sid_40
# 	Dataframe length: 24702
# 	Time taken: 5947.224467515945 s
#
# Processing sessid_38_P1_sid_56
# 	Dataframe length: 33451
# 	Time taken: 6071.978196382523 s
#
# Processing sessid_38_P2_sid_30
# 	Dataframe length: 33451
# 	Time taken: 6182.399984836578 s
#
# Processing sessid_40_P1_sid_56
# 	Dataframe length: 26215
# 	Time taken: 6272.336229324341 s
#
# Processing sessid_40_P2_sid_51
# 	Dataframe length: 26215
# 	Time taken: 6359.820317029953 s
#
# Processing sessid_41_P1_sid_57
# 	Dataframe length: 20144
# 	Time taken: 6429.512687921524 s
#
# Processing sessid_41_P2_sid_51
# 	Dataframe length: 20144
# 	Time taken: 6496.569871902466 s
#
# Processing sessid_42_P1_sid_12
# 	Dataframe length: 22047
# 	Time taken: 6564.548336029053 s
#
# Processing sessid_42_P2_sid_10
# 	Dataframe length: 22047
# 	Time taken: 6639.785073518753 s
#
# Processing sessid_43_P1_sid_12
# 	Dataframe length: 23613
# 	Time taken: 6715.229366779327 s
#
# Processing sessid_43_P2_sid_20
# 	Dataframe length: 23613
# 	Time taken: 6797.9269778728485 s
#
# Processing sessid_44_P1_sid_10
# 	Dataframe length: 9415
# 	Time taken: 6827.993297815323 s
#
# Processing sessid_44_P2_sid_20
# 	Dataframe length: 9415
# 	Time taken: 6858.919917345047 s
#
# Processing sessid_45_P1_sid_56
# 	Dataframe length: 31251
# 	Time taken: 6960.688271284103 s
#
# Processing sessid_45_P2_sid_38
# 	Dataframe length: 31251
# 	Time taken: 7065.977684259415 s
#
# Processing sessid_46_P1_sid_55
# 	Dataframe length: 9621
# 	Time taken: 7097.135233640671 s
#
# Processing sessid_46_P2_sid_38
# 	Dataframe length: 9621
# 	Time taken: 7129.310136318207 s
#
# Processing sessid_47_P1_sid_56
# 	Dataframe length: 29503
# 	Time taken: 7225.264504671097 s
#
# Processing sessid_47_P2_sid_37
# 	Dataframe length: 29503
# 	Time taken: 7317.513409614563 s
#
# Processing sessid_48_P1_sid_58
# 	Dataframe length: 23904
# 	Time taken: 7392.31408572197 s
#
# Processing sessid_48_P2_sid_37
# 	Dataframe length: 23904
# 	Time taken: 7467.653558015823 s
#
# Processing sessid_49_P1_sid_56
# 	Dataframe length: 26394
# 	Time taken: 7548.868389368057 s
#
# Processing sessid_49_P2_sid_49
# 	Dataframe length: 26394
# 	Time taken: 7632.138125896454 s
#
# Processing sessid_50_P1_sid_12
# 	Dataframe length: 25721
# 	Time taken: 7713.060355186462 s
#
# Processing sessid_50_P2_sid_31
# 	Dataframe length: 25721
# 	Time taken: 7797.866845846176 s
#
# Processing sessid_51_P1_sid_12
# 	Dataframe length: 19426
# 	Time taken: 7857.78262758255 s
#
# Processing sessid_51_P2_sid_59
# 	Dataframe length: 19426
# 	Time taken: 7925.205075740814 s
#
# Processing sessid_52_P1_sid_12
# 	Dataframe length: 20088
# 	Time taken: 7987.160039901733 s
#
# Processing sessid_52_P2_sid_08
# 	Dataframe length: 20088
# 	Time taken: 8053.369354486465 s
#
# Processing sessid_53_P1_sid_59
# 	Dataframe length: 10286
# 	Time taken: 8085.858596563339 s
#
# Processing sessid_53_P2_sid_08
# 	Dataframe length: 10286
# 	Time taken: 8119.503371477127 s
#
# Processing sessid_54_P1_sid_12
# 	Dataframe length: 22213
# 	Time taken: 8189.759818553925 s
#
# Processing sessid_54_P2_sid_60
# 	Dataframe length: 22213
# 	Time taken: 8263.712782144547 s
#
#
# Generated 106 fully-annotated feature files.
