# %% [markdown]
# # Run only once! (after OpenFace feature extraction)
# ###  *DONE*
#
# Naming convention: *sessid_{session id}_P{subject position either 1 or 2}_sid_{subject id}.csv*

# %%
#######################################################################################################################
# Project: Deep Virtual Rapport Agent (rapport model)
#
#     Jan Ondras (jo951030@gmail.com)
#     Institute for Creative Technologies, University of Southern California
#     April-October 2019
#
#######################################################################################################################
# Rename the extracted vision features csvs to follow the naming convention: 
#     sessid_{session id}P{subject position either 1 or 2}sid_{subject id}.csv
#     It uses the session.xml files from the Mimicry dataset and also the vision_feature_extraction_time_log.txt.
#######################################################################################################################


from os import rename
import glob
import pandas as pd
import xml.etree.ElementTree as ET

# Load feature extraction log (contains sessid-filename associations)
df = pd.read_csv('/home/ICT2000/jondras/dvra_datasets/mimicry/vision_feature_extraction_time_log.txt') #, header=None)
# print(df['sessid'])

# Set of subject ids
sids = set()

# Iterate over original csv feature files
for old_file_path in sorted(glob.glob('/home/ICT2000/jondras/dvra_datasets/mimicry/vision_features/original_openface_features/*.csv')):
    split_file_path = old_file_path.split('/')
    
    # Get session ID (sessid), as string
    old_filename = split_file_path[-1]
    sessid = f"{int(df[df['filename'] == old_filename[:-3] + 'avi']['sessid']):02d}"
    
    # Get subject ID (sid)
    if 'P1' in old_filename:
        pid = 'P1'
    elif 'P2' in old_filename:
        pid = 'P2'
    else:
        raise Exception('PID not recognized within the csv filename of extracted features!')
    xml_root = ET.parse(f'/home/ICT2000/jondras/dvra_datasets/mimicry/original_data/sessid_{sessid}/Sessions/{int(sessid)}/session.xml').getroot()
    sid = xml_root.find(f"./subject/[@position='{pid}']").attrib['id']
    sid = f'{int(sid):02d}'
    sids.add(sid)
    
    print(f'{sessid} {pid} {sid}')
 
    new_file_path = '/'.join(split_file_path[:-1]) + f'/sessid_{sessid}_{pid}_sid_{sid}.csv'
    rename(old_file_path, new_file_path)
    print(f'{old_file_path}\n\t renamed to: {new_file_path}')

print(f'# unique SIDs: {len(sids)}')
# Out:
# 01 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.10.05.12_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_01_P1_sid_09.csv
# 01 P2 02
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.10.05.12_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_01_P2_sid_02.csv
# 02 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.10.33.56_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_02_P1_sid_09.csv
# 02 P2 17
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.10.33.56_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_02_P2_sid_17.csv
# 03 P1 17
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.11.09.07_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_03_P1_sid_17.csv
# 03 P2 02
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.11.09.07_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_03_P2_sid_02.csv
# 04 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.12.45.32_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_04_P1_sid_12.csv
# 04 P2 23
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.12.45.32_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_04_P2_sid_23.csv
# 05 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.13.07.01_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_05_P1_sid_12.csv
# 05 P2 21
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.13.07.01_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_05_P2_sid_21.csv
# 06 P1 23
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.13.37.51_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_06_P1_sid_23.csv
# 06 P2 21
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.13.37.51_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_06_P2_sid_21.csv
# 07 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.17.07.54_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_07_P1_sid_09.csv
# 07 P2 01
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.17.07.54_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_07_P2_sid_01.csv
# 08 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.17.34.27_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_08_P1_sid_09.csv
# 08 P2 04
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.17.34.27_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_08_P2_sid_04.csv
# 09 P1 01
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.18.07.54_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_09_P1_sid_01.csv
# 09 P2 04
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.18.07.54_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_09_P2_sid_04.csv
# 10 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.19.07.40_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_10_P1_sid_09.csv
# 10 P2 34
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.15.19.07.40_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_10_P2_sid_34.csv
# 11 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.10.17.22_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_11_P1_sid_09.csv
# 11 P2 15
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.10.17.22_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_11_P2_sid_15.csv
# 12 P1 15
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.11.06.01_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_12_P1_sid_15.csv
# 12 P2 11
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.11.06.01_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_12_P2_sid_11.csv
# 13 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.12.30.53_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_13_P1_sid_09.csv
# 13 P2 19
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.12.30.53_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_13_P2_sid_19.csv
# 14 P1 19
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.13.16.01_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_14_P1_sid_19.csv
# 14 P2 06
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.13.16.01_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_14_P2_sid_06.csv
# 15 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.17.15.32_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_15_P1_sid_09.csv
# 15 P2 16
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.17.15.32_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_15_P2_sid_16.csv
# 16 P1 24
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.18.10.12_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_16_P1_sid_24.csv
# 16 P2 16
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.16.18.10.12_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_16_P2_sid_16.csv
# 17 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.10.13.20_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_17_P1_sid_09.csv
# 17 P2 43
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.10.13.20_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_17_P2_sid_43.csv
# 18 P1 03
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.11.00.58_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_18_P1_sid_03.csv
# 18 P2 43
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.11.00.58_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_18_P2_sid_43.csv
# 19 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.12.40.27_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_19_P1_sid_09.csv
# 19 P2 22
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.12.40.27_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_19_P2_sid_22.csv
# 20 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.13.00.37_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_20_P1_sid_09.csv
# 20 P2 50
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.13.00.37_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_20_P2_sid_50.csv
# 21 P1 50
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.13.30.10_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_21_P1_sid_50.csv
# 21 P2 22
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.13.30.10_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_21_P2_sid_22.csv
# 22 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.17.07.47_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_22_P1_sid_12.csv
# 22 P2 18
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.17.07.47_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_22_P2_sid_18.csv
# 23 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.17.29.53_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_23_P1_sid_12.csv
# 23 P2 39
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.17.29.53_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_23_P2_sid_39.csv
# 24 P1 18
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.18.01.56_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_24_P1_sid_18.csv
# 24 P2 39
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.17.18.01.56_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_24_P2_sid_39.csv
# 25 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.10.12.25_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_25_P1_sid_12.csv
# 25 P2 27
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.10.12.25_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_25_P2_sid_27.csv
# 26 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.10.32.51_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_26_P1_sid_12.csv
# 26 P2 32
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.10.32.51_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_26_P2_sid_32.csv
# 27 P1 27
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.10.56.28_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_27_P1_sid_27.csv
# 27 P2 32
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.10.56.28_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_27_P2_sid_32.csv
# 28 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.12.45.43_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_28_P1_sid_09.csv
# 28 P2 07
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.12.45.43_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_28_P2_sid_07.csv
# 29 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.13.06.53_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_29_P1_sid_09.csv
# 29 P2 05
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.13.06.53_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_29_P2_sid_05.csv
# 30 P1 07
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.13.30.19_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_30_P1_sid_07.csv
# 30 P2 05
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.13.30.19_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_30_P2_sid_05.csv
# 31 P1 28
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.17.05.34_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_31_P1_sid_28.csv
# 31 P2 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.17.05.34_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_31_P2_sid_09.csv
# 32 P1 28
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.17.42.14_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_32_P1_sid_28.csv
# 32 P2 14
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.18.17.42.14_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_32_P2_sid_14.csv
# 33 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.12.43.48_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_33_P1_sid_09.csv
# 33 P2 33
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.12.43.48_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_33_P2_sid_33.csv
# 34 P1 09
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.13.05.14_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_34_P1_sid_09.csv
# 34 P2 36
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.13.05.14_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_34_P2_sid_36.csv
# 35 P1 33
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.13.33.49_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_35_P1_sid_33.csv
# 35 P2 36
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.13.33.49_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_35_P2_sid_36.csv
# 36 P1 13
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.17.25.48_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_36_P1_sid_13.csv
# 36 P2 40
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.17.25.48_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_36_P2_sid_40.csv
# 37 P1 13
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.17.53.44_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_37_P1_sid_13.csv
# 37 P2 40
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.19.17.53.44_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_37_P2_sid_40.csv
# 38 P1 56
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.10.19.22_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_38_P1_sid_56.csv
# 38 P2 30
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.10.19.22_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_38_P2_sid_30.csv
# 40 P1 56
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.12.50.39_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_40_P1_sid_56.csv
# 40 P2 51
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.12.50.39_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_40_P2_sid_51.csv
# 41 P1 57
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.13.26.22_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_41_P1_sid_57.csv
# 41 P2 51
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.13.26.22_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_41_P2_sid_51.csv
# 42 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.17.08.45_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_42_P1_sid_12.csv
# 42 P2 10
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.17.08.45_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_42_P2_sid_10.csv
# 43 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.17.26.36_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_43_P1_sid_12.csv
# 43 P2 20
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.17.26.36_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_43_P2_sid_20.csv
# 44 P1 10
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.17.54.52_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_44_P1_sid_10.csv
# 44 P2 20
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.22.17.54.52_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_44_P2_sid_20.csv
# 45 P1 56
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.23.13.01.45_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_45_P1_sid_56.csv
# 45 P2 38
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.23.13.01.45_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_45_P2_sid_38.csv
# 46 P1 55
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.23.13.40.35_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_46_P1_sid_55.csv
# 46 P2 38
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.23.13.40.35_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_46_P2_sid_38.csv
# 47 P1 56
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.24.10.27.22_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_47_P1_sid_56.csv
# 47 P2 37
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.24.10.27.22_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_47_P2_sid_37.csv
# 48 P1 58
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.24.11.25.23_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_48_P1_sid_58.csv
# 48 P2 37
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.24.11.25.23_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_48_P2_sid_37.csv
# 49 P1 56
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.24.15.07.46_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_49_P1_sid_56.csv
# 49 P2 49
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.24.15.07.46_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_49_P2_sid_49.csv
# 50 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.10.43.34_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_50_P1_sid_12.csv
# 50 P2 31
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.10.43.34_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_50_P2_sid_31.csv
# 51 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.12.41.26_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_51_P1_sid_12.csv
# 51 P2 59
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.12.41.26_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_51_P2_sid_59.csv
# 52 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.13.06.23_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_52_P1_sid_12.csv
# 52 P2 08
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.13.06.23_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_52_P2_sid_08.csv
# 53 P1 59
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.13.38.11_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_53_P1_sid_59.csv
# 53 P2 08
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.25.13.38.11_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_53_P2_sid_08.csv
# 54 P1 12
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.26.09.03.52_P1_FaceFar2_06068_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_54_P1_sid_12.csv
# 54 P2 60
# /home/ICT2000/jondras/datasets/mimicry/features/2010.11.26.09.03.52_P2_FaceFar2_06060_BW1024.csv
# 	 renamed to: /home/ICT2000/jondras/datasets/mimicry/features/sessid_54_P2_sid_60.csv
# # unique SIDs: 46
