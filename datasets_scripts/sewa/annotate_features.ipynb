# %%
#######################################################################################################################
# Project: Deep Virtual Rapport Agent (data preprocessing)
#
#     Jan Ondras (jo951030@gmail.com)
#     Institute for Creative Technologies, University of Southern California
#     April-October 2019
#
#######################################################################################################################
# Annotate OpenFace features from the sewa dataset with ground-true head gestures.
#
#     Each frame will be annotated with ground-truth annotations of nod and shake head gestures
#
#     Input features: dvra_datasets/sewa/openface_features 
#     Input annotations: dvra_datasets/sewa/original_data 
#     Output features: dvra_datasets/sewa/annotated_features
#######################################################################################################################

# %%
###########################################################
import numpy as np
random_seed = 37
np.random.seed(random_seed)
from tensorflow import set_random_seed
set_random_seed(random_seed)
###########################################################

# For each recording
#     Resample feature dataframe
#     Add first derivatives of selected features
#     Annotate frames
#     Save as new annotated dataframe, 0 => not a nod, 1 => nod

import os
import glob
import pandas as pd
import scipy.signal
from scipy import interpolate
import time
import pympi    # Import pympi to work with elan files

# Unified frame rate
FRAME_RATE = 30.

# Features whose first and second derivatives will be calculated
diff_selected_features = [
    ' pose_Tx', 
    ' pose_Ty', 
    ' pose_Tz', 

    ' pose_Rx', 
    ' pose_Ry', 
    ' pose_Rz',

    ' p_rx', 
    ' p_ry',
    ' p_rz'
    
    # add landmarks?
]

input_features_dir = '/home/ICT2000/jondras/dvra_datasets/sewa/openface_features'
input_annotations_dir = '/home/ICT2000/jondras/dvra_datasets/sewa/original_data'
output_dir = '/home/ICT2000/jondras/dvra_datasets/sewa/annotated_features'

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
    
start_time = time.time()    
cnt = 0
for feature_file in sorted(glob.glob(input_features_dir + '/*.csv')):
    
    sid = feature_file.split('/')[-1].split('.')[0]
    print(f'Processing SESID {sid}')
    
    org_df = pd.read_csv(feature_file)
    print(len(org_df))
#     print(len(org_df), org_df)
    
    # Resample feature dataframe to common frame rate, if needed
    csv_frame_rate = (org_df.shape[0] - 1) / np.sum(np.diff(org_df[' timestamp']))
    print(f'\tcsv frame rate: {csv_frame_rate}')
    if round(csv_frame_rate) == FRAME_RATE:
        print(f'\tNOT resampling')
        new_df = org_df.copy()
    else:
        print(f'\tREsampling from {csv_frame_rate} to {FRAME_RATE}')
        new_df = []
        timestamps_resampled = np.arange(0., org_df.iloc[-1][' timestamp'], step=1. / FRAME_RATE)
        for col_name in org_df.columns:            
            # Get interpolation function
            f = interpolate.interp1d(x=org_df[' timestamp'], y=org_df[col_name], kind='linear')
            new_df.append( f(timestamps_resampled) )
        # Does not work properly
#         n_resampled_points = int(1 + (len(org_df[' timestamp']) - 1) * FRAME_RATE / csv_frame_rate)
#         for col_name in org_df.columns:            
#             new_col = scipy.signal.resample(np.array(org_df[col_name]), num=n_resampled_points)
#             new_df.append(new_col)
        new_df = pd.DataFrame(np.array(new_df).T, columns=org_df.columns) 
                
    # Add first and second derivatives of selected features
    diff_features = dict()
    for feature_name in diff_selected_features:
        diff_features['diff_' + feature_name] =  np.diff(new_df[feature_name], prepend=new_df[feature_name][0])
        diff_features['diff2_' + feature_name] = np.diff(diff_features['diff_' + feature_name], 
                                                         prepend=diff_features['diff_' + feature_name][0])    
    new_df = new_df.assign(**diff_features)
            
    # Annotate frames
    # Add annotation columns for nod and shake
    new_df = new_df.assign(nod=np.zeros(len(new_df), dtype=int))
    new_df = new_df.assign(shake=np.zeros(len(new_df), dtype=int))
#     print(new_df)
    
    hg_df = pd.read_csv(f'{input_annotations_dir}/{sid}/{sid}-HeadGesture.csv' )
    for _, row in hg_df.iterrows():
        # Annotation begin/end time
        interval_begin = (row['first_frame'] - 1) / csv_frame_rate
        interval_end   = row['last_frame'] / csv_frame_rate
        if row['head_gesture'] == 'Nod':
            new_df.nod = pd.np.where((new_df[' timestamp'] >= interval_begin) & (new_df[' timestamp'] <= interval_end), 
                                 1, new_df.nod)
        elif row['head_gesture'] == 'Shake':
            new_df.shake = pd.np.where((new_df[' timestamp'] >= interval_begin) & (new_df[' timestamp'] <= interval_end), 
                                 1, new_df.shake)
        else:
            raise Exception('Unknown head gesture!')
#         print(interval_begin, interval_end)
#         print(np.where(np.array(new_df.nod) == 1))
#         print(np.where(np.array(new_df.shake) == 1))
    
    # Save as new annotated dataframe
#     print(new_df)
    new_df.to_csv(f'{output_dir}/{sid}.csv', index=False)
    cnt += 1
    print(f'Time taken: {time.time() - start_time} s\n')        
#     break

print(f'\nGenerated {cnt} annotated feature files.')
# Out:
# Processing SESID SAH_C1_S001_P001_VC1_003857_004977
# 1121
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 1.4785840511322021 s
#
# Processing SESID SAH_C1_S005_P010_VC1_000001_000801
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 2.610422134399414 s
#
# Processing SESID SAH_C1_S008_P016_VC1_005601_006984
# 1384
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 4.253813028335571 s
#
# Processing SESID SAH_C1_S009_P017_VC1_004001_006201
# 2201
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 6.649529933929443 s
#
# Processing SESID SAH_C1_S009_P018_VC1_004321_005367
# 1047
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 8.105289936065674 s
#
# Processing SESID SAH_C1_S013_P025_VC1_000997_002939
# 1943
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 10.204917430877686 s
#
# Processing SESID SAH_C1_S013_P025_VC1_006901_008783
# 1883
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 12.265357255935669 s
#
# Processing SESID SAH_C1_S014_P028_VC1_000588_001854
# 1267
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 13.823644638061523 s
#
# Processing SESID SAH_C1_S018_P036_VC1_001394_002328
# 935
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 15.080946922302246 s
#
# Processing SESID SAH_C1_S022_P044_VC1_007329_008693
# 1365
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 16.716853618621826 s
#
# Processing SESID SAH_C1_S024_P048_VC1_000845_002039
# 1195
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 18.160304307937622 s
#
# Processing SESID SAH_C1_S027_P053_VC1_006932_008715
# 1784
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 20.25540542602539 s
#
# Processing SESID SAH_C1_S027_P054_VC1_000920_002082
# 1163
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 21.720568895339966 s
#
# Processing SESID SAH_C1_S028_P055_VC1_003774_004919
# 1146
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 23.328696250915527 s
#
# Processing SESID SAH_C1_S028_P056_VC1_001001_001771
# 771
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 24.502025842666626 s
#
# Processing SESID SAH_C1_S029_P057_VC1_003201_004052
# 852
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 25.719797134399414 s
#
# Processing SESID SAH_C1_S029_P058_VC1_006573_007472
# 900
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 26.99508047103882 s
#
# Processing SESID SAH_C1_S192_P384_VC1_006367_008663
# 2297
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 29.5349440574646 s
#
# Processing SESID SAH_C1_S194_P388_VC1_003531_004419
# 889
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 30.781723022460938 s
#
# Processing SESID SAH_C2_S034_P067_VC1_005252_005735
# 484
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 31.756968021392822 s
#
# Processing SESID SAH_C2_S034_P068_VC1_002702_003395
# 694
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 32.92991399765015 s
#
# Processing SESID SAH_C2_S036_P072_VC1_001337_002056
# 720
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 34.10701847076416 s
#
# Processing SESID SAH_C2_S037_P073_VC1_002345_002998
# 654
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 35.14655542373657 s
#
# Processing SESID SAH_C2_S037_P074_VC1_002225_003088
# 864
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 36.39918041229248 s
#
# Processing SESID SAH_C2_S044_P087_VC1_000002_000683
# 682
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 37.57403516769409 s
#
# Processing SESID SAH_C2_S044_P088_VC1_000834_001365
# 532
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 38.4546480178833 s
#
# Processing SESID SAH_C2_S045_P089_VC1_003626_005086
# 1461
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 40.173728704452515 s
#
# Processing SESID SAH_C2_S045_P090_VC1_002801_003385
# 585
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 41.08302664756775 s
#
# Processing SESID SAH_C2_S046_P091_VC1_004297_005075
# 779
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 42.16786336898804 s
#
# Processing SESID SAH_C2_S047_P093_VC1_000538_001078
# 541
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 42.98973536491394 s
#
# Processing SESID SAH_C2_S047_P094_VC1_002101_002718
# 618
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 43.927733421325684 s
#
# Processing SESID SAH_C2_S049_P097_VC1_003219_004772
# 1554
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 45.864922761917114 s
#
# Processing SESID SAH_C2_S050_P100_VC1_002799_003301
# 503
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 46.7767288684845 s
#
# Processing SESID SAH_C2_S059_P117_VC1_000601_001353
# 753
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 47.80718541145325 s
#
# Processing SESID SAH_C2_S062_P123_VC1_000489_001586
# 1098
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 49.272725343704224 s
#
# Processing SESID SAH_C3_S063_P126_VC1_004386_004882
# 497
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 50.07665157318115 s
#
# Processing SESID SAH_C3_S064_P127_VC1_003781_004651
# 871
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 51.26891040802002 s
#
# Processing SESID SAH_C3_S067_P134_VC1_003251_003561
# 311
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 51.91827464103699 s
#
# Processing SESID SAH_C3_S069_P138_VC1_003001_004571
# 1571
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 53.766716957092285 s
#
# Processing SESID SAH_C3_S070_P139_VC1_002551_003581
# 1031
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 55.1446578502655 s
#
# Processing SESID SAH_C3_S074_P147_VC1_001621_002041
# 421
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 55.90384483337402 s
#
# Processing SESID SAH_C3_S075_P150_VC1_001951_002465
# 515
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 56.759641885757446 s
#
# Processing SESID SAH_C3_S076_P152_VC1_004381_005301
# 921
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 58.00199556350708 s
#
# Processing SESID SAH_C3_S077_P154_VC1_004201_004981
# 781
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 59.08483004570007 s
#
# Processing SESID SAH_C3_S082_P164_VC1_000521_001701
# 1181
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 60.68797564506531 s
#
# Processing SESID SAH_C3_S084_P167_VC1_000621_001141
# 521
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 61.54342246055603 s
#
# Processing SESID SAH_C3_S087_P173_VC1_004601_004981
# 381
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 62.28425335884094 s
#
# Processing SESID SAH_C3_S090_P179_VC1_001981_002451
# 471
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 63.090176820755005 s
#
# Processing SESID SAH_C3_S092_P184_VC1_001701_003051
# 1351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 64.87976455688477 s
#
# Processing SESID SAH_C3_S093_P186_VC1_005551_006461
# 911
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 66.24162030220032 s
#
# Processing SESID SAH_C4_S095_P189_VC1_006301_006750
# 450
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 67.04480147361755 s
#
# Processing SESID SAH_C4_S095_P190_VC1_002601_003100
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 67.862375497818 s
#
# Processing SESID SAH_C4_S096_P191_VC1_000151_000800
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 68.87845754623413 s
#
# Processing SESID SAH_C4_S097_P193_VC1_003701_004200
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 69.68983054161072 s
#
# Processing SESID SAH_C4_S097_P194_VC1_001351_002550
# 1200
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 71.20301222801208 s
#
# Processing SESID SAH_C4_S098_P196_VC1_001501_002350
# 850
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 72.39603734016418 s
#
# Processing SESID SAH_C4_S110_P219_VC1_001651_002950
# 1300
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 74.09485077857971 s
#
# Processing SESID SAH_C4_S111_P221_VC1_001951_003500
# 1550
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 76.09259104728699 s
#
# Processing SESID SAH_C4_S112_P224_VC1_004801_005450
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 77.1158800125122 s
#
# Processing SESID SAH_C4_S113_P226_VC1_002701_003600
# 900
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 78.48111629486084 s
#
# Processing SESID SAH_C4_S116_P232_VC1_007551_008500
# 950
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 79.82185864448547 s
#
# Processing SESID SAH_C4_S118_P236_VC1_001151_002250
# 1100
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 81.1899163722992 s
#
# Processing SESID SAH_C4_S120_P239_VC1_006551_007250
# 700
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 82.28253817558289 s
#
# Processing SESID SAH_C4_S122_P244_VC1_003301_004400
# 1100
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 83.79668998718262 s
#
# Processing SESID SAH_C4_S126_P251_VC1_007101_008750
# 1650
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 85.69549894332886 s
#
# Processing SESID SAH_C5_S128_P255_VC1_001601_002101
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 86.53025436401367 s
#
# Processing SESID SAH_C5_S131_P261_VC1_008001_008501
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 87.4256374835968 s
#
# Processing SESID SAH_C5_S132_P263_VC1_001151_001601
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 88.22223544120789 s
#
# Processing SESID SAH_C5_S132_P264_VC1_004001_004501
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 89.13246822357178 s
#
# Processing SESID SAH_C5_S134_P267_VC1_004301_004601
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 89.77339458465576 s
#
# Processing SESID SAH_C5_S138_P275_VC1_005601_006401
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 90.95993566513062 s
#
# Processing SESID SAH_C5_S139_P278_VC1_000501_000751
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 91.56688070297241 s
#
# Processing SESID SAH_C5_S140_P279_VC1_002601_002901
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 92.2051100730896 s
#
# Processing SESID SAH_C5_S143_P285_VC1_007901_008301
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 92.9479148387909 s
#
# Processing SESID SAH_C5_S146_P292_VC1_002901_003151
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 93.53611540794373 s
#
# Processing SESID SAH_C5_S147_P293_VC1_006401_006701
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 94.18744492530823 s
#
# Processing SESID SAH_C5_S148_P295_VC1_002201_002651
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 94.9676742553711 s
#
# Processing SESID SAH_C5_S154_P307_VC1_003751_004501
# 751
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 96.08129787445068 s
#
# Processing SESID SAH_C5_S159_P318_VC1_003651_004101
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 96.89882135391235 s
#
# Processing SESID SAH_C5_S163_P325_VC1_002001_002301
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 97.59021139144897 s
#
# Processing SESID SAH_C6_S166_P332_VC1_005000_006160
# 1161
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 99.18177938461304 s
#
# Processing SESID SAH_C6_S169_P338_VC1_005506_006434
# 929
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 100.39335918426514 s
#
# Processing SESID SAH_C6_S173_P345_VC1_004337_005548
# 1212
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 101.9011447429657 s
#
# Processing SESID SAH_C6_S174_P347_VC1_002547_003074
# 528
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 102.76042699813843 s
#
# Processing SESID SAH_C6_S180_P360_VC1_003302_004131
# 830
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 103.82866621017456 s
#
# Processing SESID SAH_C6_S181_P362_VC1_000742_001590
# 849
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 104.95599007606506 s
#
# Processing SESID SAH_C6_S182_P363_VC1_008007_008745
# 739
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 106.12604475021362 s
#
# Processing SESID SAH_C6_S182_P364_VC1_004368_005319
# 952
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 107.40117049217224 s
#
# Processing SESID SAH_C6_S183_P366_VC1_002795_003506
# 712
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 108.38250255584717 s
#
# Processing SESID SAH_C6_S184_P368_VC1_007815_008614
# 800
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 109.41600346565247 s
#
# Processing SESID SAH_C6_S186_P371_VC1_004196_005329
# 1134
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 110.88544249534607 s
#
# Processing SESID SAH_C6_S187_P373_VC1_000125_002108
# 1984
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 113.25840210914612 s
#
# Processing SESID SAH_C6_S187_P374_VC1_003581_004166
# 586
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 114.20712184906006 s
#
# Processing SESID SAH_C6_S188_P376_VC1_002183_002875
# 693
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 115.20057415962219 s
#
# Processing SESID SAH_C6_S190_P380_VC1_002402_003213
# 812
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 116.29473638534546 s
#
# Processing SESID SAL_C1_S001_P002_VC1_000921_001732
# 812
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 117.3978259563446 s
#
# Processing SESID SAL_C1_S002_P004_VC1_002601_003428
# 828
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 118.48822522163391 s
#
# Processing SESID SAL_C1_S003_P006_VC1_001561_002366
# 806
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 119.5413818359375 s
#
# Processing SESID SAL_C1_S007_P013_VC1_001301_002076
# 776
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 120.57642340660095 s
#
# Processing SESID SAL_C1_S007_P014_VC1_002076_003143
# 1068
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 121.80932664871216 s
#
# Processing SESID SAL_C1_S010_P020_VC1_002611_003701
# 1091
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 123.12588548660278 s
#
# Processing SESID SAL_C1_S011_P022_VC1_006951_008001
# 1051
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 124.41421175003052 s
#
# Processing SESID SAL_C1_S012_P024_VC1_006001_008775
# 2775
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 127.21567368507385 s
#
# Processing SESID SAL_C1_S016_P031_VC1_001801_003001
# 1201
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 128.68059372901917 s
#
# Processing SESID SAL_C1_S016_P031_VC1_004201_005001
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 129.7764892578125 s
#
# Processing SESID SAL_C1_S017_P034_VC1_001001_003801
# 2801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 132.6086871623993 s
#
# Processing SESID SAL_C1_S019_P038_VC1_005801_008601
# 2801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 135.4663691520691 s
#
# Processing SESID SAL_C1_S021_P041_VC1_004951_006354
# 1404
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 137.0405719280243 s
#
# Processing SESID SAL_C1_S024_P047_VC1_002039_003624
# 1586
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 138.77252554893494 s
#
# Processing SESID SAL_C1_S025_P050_VC1_000701_001916
# 1216
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 140.33776235580444 s
#
# Processing SESID SAL_C1_S029_P057_VC1_005264_006249
# 986
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 141.57962846755981 s
#
# Processing SESID SAL_C1_S031_P062_VC1_001438_002301
# 864
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 142.72123908996582 s
#
# Processing SESID SAL_C2_S035_P070_VC1_001373_002439
# 1067
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 144.0867145061493 s
#
# Processing SESID SAL_C2_S038_P075_VC1_004032_005262
# 1231
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 145.55414867401123 s
#
# Processing SESID SAL_C2_S038_P076_VC1_001881_002782
# 902
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 146.73221850395203 s
#
# Processing SESID SAL_C2_S041_P081_VC1_003415_004258
# 844
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 147.78695368766785 s
#
# Processing SESID SAL_C2_S042_P083_VC1_001958_003364
# 1407
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 149.44669580459595 s
#
# Processing SESID SAL_C2_S044_P087_VC1_004155_004862
# 708
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 150.45340609550476 s
#
# Processing SESID SAL_C2_S046_P092_VC1_002832_004061
# 1230
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 151.9069640636444 s
#
# Processing SESID SAL_C2_S048_P095_VC1_003085_003710
# 626
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 152.85993313789368 s
#
# Processing SESID SAL_C2_S048_P096_VC1_000837_001711
# 875
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 153.94372534751892 s
#
# Processing SESID SAL_C2_S050_P099_VC1_003700_004484
# 785
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 154.99128031730652 s
#
# Processing SESID SAL_C2_S052_P103_VC1_003842_004770
# 929
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 156.20331358909607 s
#
# Processing SESID SAL_C2_S052_P104_VC1_004088_004607
# 520
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 157.04825592041016 s
#
# Processing SESID SAL_C2_S195_P389_VC1_002919_005001
# 2083
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 159.25510144233704 s
#
# Processing SESID SAL_C2_S195_P390_VC1_000301_002883
# 2583
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 161.97445392608643 s
#
# Processing SESID SAL_C2_S197_P393_VC1_000787_002868
# 2082
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 164.23461818695068 s
#
# Processing SESID SAL_C2_S199_P398_VC1_000467_002764
# 2298
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 167.11992383003235 s
#
# Processing SESID SAL_C3_S063_P125_VC1_006551_006901
# 351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 167.82612943649292 s
#
# Processing SESID SAL_C3_S064_P128_VC1_000381_000771
# 391
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 168.52859735488892 s
#
# Processing SESID SAL_C3_S065_P129_VC1_006021_006651
# 631
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 169.4896855354309 s
#
# Processing SESID SAL_C3_S065_P130_VC1_006901_007331
# 431
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 170.22373294830322 s
#
# Processing SESID SAL_C3_S066_P132_VC1_003361_004041
# 681
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 171.22078156471252 s
#
# Processing SESID SAL_C3_S068_P135_VC1_002501_003381
# 881
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 172.33218598365784 s
#
# Processing SESID SAL_C3_S068_P136_VC1_001721_002501
# 781
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 173.3624587059021 s
#
# Processing SESID SAL_C3_S071_P141_VC1_003501_004021
# 521
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 174.19415950775146 s
#
# Processing SESID SAL_C3_S072_P144_VC1_001141_001761
# 621
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 175.09586215019226 s
#
# Processing SESID SAL_C3_S075_P149_VC1_003251_004001
# 751
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 176.13397336006165 s
#
# Processing SESID SAL_C3_S079_P158_VC1_000701_002111
# 1411
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 177.78122544288635 s
#
# Processing SESID SAL_C3_S083_P165_VC1_003801_004791
# 991
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 179.00505948066711 s
#
# Processing SESID SAL_C3_S086_P171_VC1_006801_007631
# 831
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 180.17305493354797 s
#
# Processing SESID SAL_C3_S091_P181_VC1_000781_001951
# 1171
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 181.59731650352478 s
#
# Processing SESID SAL_C3_S093_P185_VC1_000601_001301
# 701
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 182.59613370895386 s
#
# Processing SESID SAL_C4_S095_P189_VC1_004951_005150
# 200
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 183.12667441368103 s
#
# Processing SESID SAL_C4_S096_P191_VC1_006001_006550
# 550
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 183.94674801826477 s
#
# Processing SESID SAL_C4_S097_P193_VC1_000051_000500
# 450
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 184.69540691375732 s
#
# Processing SESID SAL_C4_S097_P194_VC1_000501_001200
# 700
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 185.65815901756287 s
#
# Processing SESID SAL_C4_S099_P198_VC1_001851_002350
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 186.43797087669373 s
#
# Processing SESID SAL_C4_S101_P201_VC1_000001_000900
# 900
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 187.59070658683777 s
#
# Processing SESID SAL_C4_S108_P216_VC1_004201_005750
# 1550
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 189.3733365535736 s
#
# Processing SESID SAL_C4_S109_P217_VC1_000001_001150
# 1150
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 190.69437074661255 s
#
# Processing SESID SAL_C4_S110_P220_VC1_003401_004000
# 600
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 191.58630514144897 s
#
# Processing SESID SAL_C4_S111_P221_VC1_000901_001550
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 192.5796558856964 s
#
# Processing SESID SAL_C4_S112_P224_VC1_000451_001050
# 600
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 193.43872117996216 s
#
# Processing SESID SAL_C4_S114_P227_VC1_003851_005200
# 1350
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 194.9572970867157 s
#
# Processing SESID SAL_C4_S115_P229_VC1_001101_002000
# 900
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 196.0883150100708 s
#
# Processing SESID SAL_C4_S115_P230_VC1_000001_001050
# 1050
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 197.431560754776 s
#
# Processing SESID SAL_C4_S116_P232_VC1_002801_003500
# 700
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 198.40597486495972 s
#
# Processing SESID SAL_C5_S132_P263_VC1_003001_003401
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 199.1174669265747 s
#
# Processing SESID SAL_C6_S164_P327_VC1_005315_006833
# 1519
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 200.8674190044403 s
#
# Processing SESID SAL_C6_S164_P328_VC1_000787_001615
# 829
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 201.97811198234558 s
#
# Processing SESID SAL_C6_S166_P331_VC1_007901_008565
# 665
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 202.91664338111877 s
#
# Processing SESID SAL_C6_S166_P332_VC1_006654_007244
# 591
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 203.7696270942688 s
#
# Processing SESID SAL_C6_S168_P336_VC1_004701_005407
# 707
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 204.7699592113495 s
#
# Processing SESID SAL_C6_S170_P339_VC1_003649_005273
# 1625
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 206.69087958335876 s
#
# Processing SESID SAL_C6_S174_P348_VC1_003051_003980
# 930
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 207.88598680496216 s
#
# Processing SESID SAL_C6_S175_P350_VC1_008159_008663
# 505
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 208.65218925476074 s
#
# Processing SESID SAL_C6_S176_P352_VC1_005660_006889
# 1230
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 210.16327953338623 s
#
# Processing SESID SAL_C6_S177_P354_VC1_000116_002259
# 2144
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 212.3991355895996 s
#
# Processing SESID SAL_C6_S179_P358_VC1_001277_003963
# 2687
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 215.20308637619019 s
#
# Processing SESID SAL_C6_S185_P370_VC1_006763_007716
# 954
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 216.43781542778015 s
#
# Processing SESID SAL_C6_S188_P375_VC1_004920_006091
# 1172
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 217.89582991600037 s
#
# Processing SESID SAL_C6_S191_P381_VC1_004792_006827
# 2036
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 220.0943341255188 s
#
# Processing SESID SSD_C1_S001_P001_VC1_004201_005201
# 1001
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 221.35920596122742 s
#
# Processing SESID SSD_C1_S001_P002_VC1_002001_002701
# 701
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 222.34079217910767 s
#
# Processing SESID SSD_C1_S004_P007_VC1_001001_001901
# 901
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 223.48878622055054 s
#
# Processing SESID SSD_C1_S006_P012_VC1_002101_002801
# 701
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 224.55274295806885 s
#
# Processing SESID SSD_C1_S012_P023_VC1_002701_003301
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 225.4504120349884 s
#
# Processing SESID SSD_C1_S014_P027_VC1_003101_004001
# 901
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 226.63504576683044 s
#
# Processing SESID SSD_C1_S014_P027_VC1_004401_005801
# 1401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 228.27093243598938 s
#
# Processing SESID SSD_C1_S018_P036_VC1_002801_003601
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 229.35878086090088 s
#
# Processing SESID SSD_C1_S022_P044_VC1_003301_004101
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 230.4208846092224 s
#
# Processing SESID SSD_C1_S022_P044_VC1_007401_008001
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 231.3205156326294 s
#
# Processing SESID SSD_C1_S023_P045_VC1_001801_002201
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 232.03109049797058 s
#
# Processing SESID SSD_C1_S023_P045_VC1_003701_004001
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 232.66266536712646 s
#
# Processing SESID SSD_C1_S023_P046_VC1_003001_003501
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 233.44990396499634 s
#
# Processing SESID SSD_C1_S025_P049_VC1_004201_004601
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 234.14488768577576 s
#
# Processing SESID SSD_C1_S025_P050_VC1_004701_005301
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 235.0482521057129 s
#
# Processing SESID SSD_C1_S026_P052_VC1_001101_001901
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 236.18980956077576 s
#
# Processing SESID SSD_C1_S027_P053_VC1_002401_003901
# 1501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 237.9107642173767 s
#
# Processing SESID SSD_C1_S029_P058_VC1_000601_001201
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 238.80924272537231 s
#
# Processing SESID SSD_C1_S193_P385_VC1_004901_006301
# 1401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 240.44825768470764 s
#
# Processing SESID SSD_C2_S033_P066_VC1_002292_002717
# 426
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 241.17820167541504 s
#
# Processing SESID SSD_C2_S035_P069_VC1_002352_003021
# 670
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 242.10055303573608 s
#
# Processing SESID SSD_C2_S037_P073_VC1_000788_001622
# 835
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 243.2120716571808 s
#
# Processing SESID SSD_C2_S038_P075_VC1_004130_004815
# 686
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 244.15976405143738 s
#
# Processing SESID SSD_C2_S038_P076_VC1_001890_002661
# 772
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 245.24400162696838 s
#
# Processing SESID SSD_C2_S041_P081_VC1_003460_004029
# 570
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 246.0659818649292 s
#
# Processing SESID SSD_C2_S042_P083_VC1_002694_003374
# 681
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 247.01362085342407 s
#
# Processing SESID SSD_C2_S044_P088_VC1_001984_003108
# 1125
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 248.39616084098816 s
#
# Processing SESID SSD_C2_S047_P093_VC1_000523_001060
# 538
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 249.28293251991272 s
#
# Processing SESID SSD_C2_S048_P096_VC1_004264_004849
# 586
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 250.11214351654053 s
#
# Processing SESID SSD_C2_S049_P097_VC1_003128_003877
# 750
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 251.16010570526123 s
#
# Processing SESID SSD_C2_S050_P099_VC1_003700_004297
# 598
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 252.04855942726135 s
#
# Processing SESID SSD_C2_S050_P100_VC1_003006_003716
# 711
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 253.08222675323486 s
#
# Processing SESID SSD_C2_S060_P120_VC1_000467_000955
# 489
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 253.88242101669312 s
#
# Processing SESID SSD_C2_S061_P121_VC1_000601_001372
# 772
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 254.9800853729248 s
#
# Processing SESID SSD_C2_S062_P123_VC1_000734_001657
# 924
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 256.22750973701477 s
#
# Processing SESID SSD_C2_S062_P124_VC1_001541_002516
# 976
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 257.457129240036 s
#
# Processing SESID SSD_C2_S195_P389_VC1_003001_006450
# 3450
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 260.7730541229248 s
#
# Processing SESID SSD_C2_S195_P390_VC1_000301_002910
# 2610
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 263.4040994644165 s
#
# Processing SESID SSD_C2_S197_P393_VC1_000817_002713
# 1897
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 265.44970703125 s
#
# Processing SESID SSD_C3_S064_P127_VC1_002051_002701
# 651
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 266.44081139564514 s
#
# Processing SESID SSD_C3_S072_P143_VC1_001771_002541
# 771
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 267.5243434906006 s
#
# Processing SESID SSD_C3_S074_P148_VC1_001201_001631
# 431
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 268.2725577354431 s
#
# Processing SESID SSD_C3_S075_P149_VC1_007631_007931
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 268.8901541233063 s
#
# Processing SESID SSD_C3_S077_P154_VC1_003071_003801
# 731
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 269.89004349708557 s
#
# Processing SESID SSD_C3_S078_P156_VC1_003001_004501
# 1501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 271.5785584449768 s
#
# Processing SESID SSD_C3_S079_P157_VC1_006691_008021
# 1331
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 273.1497542858124 s
#
# Processing SESID SSD_C3_S079_P158_VC1_002151_003421
# 1271
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 274.6456067562103 s
#
# Processing SESID SSD_C3_S080_P160_VC1_006141_007751
# 1611
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 276.4738883972168 s
#
# Processing SESID SSD_C3_S082_P163_VC1_001711_003281
# 1571
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 278.2858500480652 s
#
# Processing SESID SSD_C3_S085_P170_VC1_004931_005601
# 671
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 279.2315707206726 s
#
# Processing SESID SSD_C3_S087_P173_VC1_002141_002821
# 681
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 280.21577858924866 s
#
# Processing SESID SSD_C3_S087_P174_VC1_002951_003961
# 1011
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 281.521390914917 s
#
# Processing SESID SSD_C3_S091_P181_VC1_005501_007401
# 1901
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 283.5879418849945 s
#
# Processing SESID SSD_C3_S092_P183_VC1_003651_004631
# 981
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 284.86426639556885 s
#
# Processing SESID SSD_C4_S096_P191_VC1_001501_002000
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 285.6525478363037 s
#
# Processing SESID SSD_C4_S097_P193_VC1_000601_001000
# 400
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 286.3526945114136 s
#
# Processing SESID SSD_C4_S097_P194_VC1_002451_003100
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 287.2876799106598 s
#
# Processing SESID SSD_C4_S101_P202_VC1_001251_001750
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 288.0750937461853 s
#
# Processing SESID SSD_C4_S101_P202_VC1_004951_006350
# 1400
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 289.64163279533386 s
#
# Processing SESID SSD_C4_S106_P212_VC1_003701_004200
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 290.43596839904785 s
#
# Processing SESID SSD_C4_S107_P214_VC1_003801_005300
# 1500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 292.1910183429718 s
#
# Processing SESID SSD_C4_S111_P221_VC1_000651_001500
# 850
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 293.31093645095825 s
#
# Processing SESID SSD_C4_S111_P222_VC1_000901_001550
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 294.2437605857849 s
#
# Processing SESID SSD_C4_S111_P222_VC1_003501_004150
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 295.24555683135986 s
#
# Processing SESID SSD_C4_S112_P224_VC1_002001_003300
# 1300
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 296.8270971775055 s
#
# Processing SESID SSD_C4_S114_P227_VC1_002501_003850
# 1350
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 298.41021847724915 s
#
# Processing SESID SSD_C4_S116_P232_VC1_001001_001500
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 299.2092628479004 s
#
# Processing SESID SSD_C4_S117_P233_VC1_000701_002850
# 2150
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 301.5382673740387 s
#
# Processing SESID SSD_C4_S117_P234_VC1_002801_003500
# 700
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 302.50635838508606 s
#
# Processing SESID SSD_C5_S128_P255_VC1_004601_005151
# 551
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 303.35494923591614 s
#
# Processing SESID SSD_C5_S128_P255_VC1_005951_006221
# 271
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 303.9404766559601 s
#
# Processing SESID SSD_C5_S131_P262_VC1_005101_005651
# 551
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 304.77476716041565 s
#
# Processing SESID SSD_C5_S133_P266_VC1_007451_007901
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 305.53945207595825 s
#
# Processing SESID SSD_C5_S135_P269_VC1_004101_004301
# 201
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 306.06366658210754 s
#
# Processing SESID SSD_C5_S136_P272_VC1_006801_007501
# 701
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 307.08655619621277 s
#
# Processing SESID SSD_C5_S138_P275_VC1_001001_001401
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 307.90624618530273 s
#
# Processing SESID SSD_C5_S138_P275_VC1_002101_002451
# 351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 308.6065032482147 s
#
# Processing SESID SSD_C5_S139_P278_VC1_003101_003201
# 101
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 309.06549882888794 s
#
# Processing SESID SSD_C5_S139_P278_VC1_005801_006051
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 309.63683581352234 s
#
# Processing SESID SSD_C5_S140_P279_VC1_001201_001401
# 201
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 310.1799547672272 s
#
# Processing SESID SSD_C5_S140_P280_VC1_001901_002051
# 151
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 310.6736488342285 s
#
# Processing SESID SSD_C5_S140_P280_VC1_006501_006751
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 311.276789188385 s
#
# Processing SESID SSD_C5_S141_P282_VC1_001901_002301
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 311.976749420166 s
#
# Processing SESID SSD_C5_S143_P285_VC1_002401_002651
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 312.5511472225189 s
#
# Processing SESID SSD_C5_S143_P286_VC1_001201_001801
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 313.48620438575745 s
#
# Processing SESID SSD_C5_S154_P307_VC1_000751_001201
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 314.23017477989197 s
#
# Processing SESID SSD_C6_S164_P328_VC1_000613_003352
# 2740
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 317.13159918785095 s
#
# Processing SESID SSD_C6_S165_P330_VC1_002018_003436
# 1419
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 318.88162875175476 s
#
# Processing SESID SSD_C6_S167_P334_VC1_001148_002373
# 1226
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 320.42045521736145 s
#
# Processing SESID SSD_C6_S171_P342_VC1_001180_004103
# 2924
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 323.4507510662079 s
#
# Processing SESID SSD_C6_S174_P348_VC1_003001_005865
# 2865
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 326.4045033454895 s
#
# Processing SESID SSD_C6_S177_P354_VC1_001212_003141
# 1930
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 328.40940284729004 s
#
# Processing SESID SSD_C6_S181_P361_VC1_001769_003101
# 1333
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 329.98964166641235 s
#
# Processing SESID SSD_C6_S181_P362_VC1_003101_004491
# 1391
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 331.5896728038788 s
#
# Processing SESID SSD_C6_S182_P363_VC1_000428_001536
# 1109
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 333.02158641815186 s
#
# Processing SESID SSD_C6_S182_P364_VC1_001445_002179
# 735
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 334.1044485569 s
#
# Processing SESID SSD_C6_S183_P365_VC1_000796_002910
# 2115
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 336.375200510025 s
#
# Processing SESID SSD_C6_S190_P379_VC1_000266_001656
# 1391
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 338.0195806026459 s
#
# Processing SESID SSD_C6_S190_P380_VC1_001527_006847
# 5321
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 343.16807436943054 s
#
# Processing SESID SSD_C6_S191_P381_VC1_000674_004625
# 3952
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 347.1891050338745 s
#
# Processing SESID SSD_C6_S191_P382_VC1_001534_003128
# 1595
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 349.055513381958 s
#
# Processing SESID SSL_C1_S001_P001_VC1_008151_008771
# 621
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 349.96788001060486 s
#
# Processing SESID SSL_C1_S005_P010_VC1_000001_001401
# 1401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 351.63084959983826 s
#
# Processing SESID SSL_C1_S008_P015_VC1_003401_004201
# 801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 352.66236567497253 s
#
# Processing SESID SSL_C1_S009_P018_VC1_004301_005301
# 1001
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 353.9184236526489 s
#
# Processing SESID SSL_C1_S013_P025_VC1_001001_001601
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 354.8146986961365 s
#
# Processing SESID SSL_C1_S014_P028_VC1_000601_001201
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 355.72428727149963 s
#
# Processing SESID SSL_C1_S018_P035_VC1_002201_002701
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 356.51263999938965 s
#
# Processing SESID SSL_C1_S018_P035_VC1_004301_004601
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 357.1083252429962 s
#
# Processing SESID SSL_C1_S020_P039_VC1_006701_007701
# 1001
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 358.3685646057129 s
#
# Processing SESID SSL_C1_S022_P043_VC1_004901_005301
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 359.08071851730347 s
#
# Processing SESID SSL_C1_S022_P044_VC1_000901_002201
# 1301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 360.6917932033539 s
#
# Processing SESID SSL_C1_S024_P048_VC1_005801_006801
# 1001
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 361.9792790412903 s
#
# Processing SESID SSL_C1_S029_P057_VC1_003151_003901
# 751
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 363.0080246925354 s
#
# Processing SESID SSL_C1_S030_P060_VC1_002301_002701
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 363.70176815986633 s
#
# Processing SESID SSL_C1_S194_P387_VC1_002301_003501
# 1201
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 365.1685564517975 s
#
# Processing SESID SSL_C1_S194_P387_VC1_004401_005501
# 1101
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 366.5844886302948 s
#
# Processing SESID SSL_C1_S194_P388_VC1_005501_005901
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 367.2820806503296 s
#
# Processing SESID SSL_C2_S034_P067_VC1_001606_002132
# 527
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 368.1006586551666 s
#
# Processing SESID SSL_C2_S035_P070_VC1_002850_003342
# 493
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 368.8914258480072 s
#
# Processing SESID SSL_C2_S036_P072_VC1_003807_004318
# 512
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 369.715469121933 s
#
# Processing SESID SSL_C2_S037_P074_VC1_003118_003727
# 610
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 370.6617753505707 s
#
# Processing SESID SSL_C2_S040_P080_VC1_001439_002035
# 597
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 371.54026222229004 s
#
# Processing SESID SSL_C2_S043_P085_VC1_002183_003099
# 917
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 372.8070526123047 s
#
# Processing SESID SSL_C2_S044_P087_VC1_004101_005335
# 1235
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 374.28621649742126 s
#
# Processing SESID SSL_C2_S045_P089_VC1_003601_005081
# 1481
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 375.97516894340515 s
#
# Processing SESID SSL_C2_S048_P095_VC1_003010_003647
# 638
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 376.95186972618103 s
#
# Processing SESID SSL_C2_S052_P104_VC1_003251_003928
# 678
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 377.9163200855255 s
#
# Processing SESID SSL_C2_S055_P109_VC1_004803_005542
# 740
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 378.95323491096497 s
#
# Processing SESID SSL_C2_S057_P114_VC1_001870_002736
# 867
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 380.12539315223694 s
#
# Processing SESID SSL_C2_S059_P117_VC1_000652_001844
# 1193
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 381.5897707939148 s
#
# Processing SESID SSL_C2_S059_P118_VC1_001262_002521
# 1260
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 383.1022906303406 s
#
# Processing SESID SSL_C2_S199_P398_VC1_000763_002709
# 1947
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 385.1919791698456 s
#
# Processing SESID SSL_C3_S065_P129_VC1_002026_002801
# 776
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 386.32342553138733 s
#
# Processing SESID SSL_C3_S068_P135_VC1_002771_003381
# 611
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 387.2216718196869 s
#
# Processing SESID SSL_C3_S072_P143_VC1_002971_003451
# 481
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 388.08247208595276 s
#
# Processing SESID SSL_C3_S075_P150_VC1_001951_003081
# 1131
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 389.4899594783783 s
#
# Processing SESID SSL_C3_S077_P154_VC1_006701_007121
# 421
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 390.21824073791504 s
#
# Processing SESID SSL_C3_S080_P159_VC1_002321_002621
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 390.8318326473236 s
#
# Processing SESID SSL_C3_S081_P161_VC1_001601_003201
# 1601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 392.6767840385437 s
#
# Processing SESID SSL_C3_S083_P165_VC1_000251_001301
# 1051
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 393.9744396209717 s
#
# Processing SESID SSL_C3_S083_P166_VC1_001301_001651
# 351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 394.66519355773926 s
#
# Processing SESID SSL_C3_S087_P173_VC1_007401_008101
# 701
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 395.7771677970886 s
#
# Processing SESID SSL_C3_S089_P177_VC1_002751_003981
# 1231
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 397.3012902736664 s
#
# Processing SESID SSL_C3_S089_P178_VC1_000451_001001
# 551
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 398.17742109298706 s
#
# Processing SESID SSL_C3_S091_P181_VC1_004551_005501
# 951
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 399.45655608177185 s
#
# Processing SESID SSL_C3_S091_P182_VC1_004281_004521
# 241
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 400.0149972438812 s
#
# Processing SESID SSL_C3_S093_P185_VC1_004801_005551
# 751
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 401.15394139289856 s
#
# Processing SESID SSL_C4_S095_P189_VC1_004451_004800
# 350
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 401.81560468673706 s
#
# Processing SESID SSL_C4_S095_P190_VC1_007201_007400
# 200
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 402.35203981399536 s
#
# Processing SESID SSL_C4_S097_P193_VC1_006351_007100
# 750
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 403.4117293357849 s
#
# Processing SESID SSL_C4_S105_P209_VC1_001751_002400
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 404.3278148174286 s
#
# Processing SESID SSL_C4_S105_P210_VC1_007751_008250
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 405.1148488521576 s
#
# Processing SESID SSL_C4_S106_P212_VC1_000701_001700
# 1000
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 406.35957884788513 s
#
# Processing SESID SSL_C4_S108_P215_VC1_003201_003700
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 407.2011103630066 s
#
# Processing SESID SSL_C4_S108_P215_VC1_004101_005800
# 1700
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 409.15211486816406 s
#
# Processing SESID SSL_C4_S111_P221_VC1_004201_004850
# 650
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 410.1176190376282 s
#
# Processing SESID SSL_C4_S113_P226_VC1_001501_002100
# 600
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 411.010445356369 s
#
# Processing SESID SSL_C4_S114_P227_VC1_002951_004800
# 1850
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 413.025621175766 s
#
# Processing SESID SSL_C4_S119_P237_VC1_001101_001950
# 850
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 414.1957383155823 s
#
# Processing SESID SSL_C4_S123_P245_VC1_005551_006200
# 650
# 	csv frame rate: 50.0
# ...
# 	REsampling from 50.0 to 30.0
# Time taken: 522.2711551189423 s
#
# Processing SESID SVH_C5_S131_P262_VC1_007201_007901
# 701
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 523.5096998214722 s
#
# Processing SESID SVH_C5_S137_P274_VC1_001401_001901
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 524.288421869278 s
#
# Processing SESID SVH_C5_S139_P278_VC1_001901_002201
# 301
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 524.9306199550629 s
#
# Processing SESID SVH_C5_S142_P283_VC1_002551_003001
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 525.6598558425903 s
#
# Processing SESID SVH_C5_S143_P285_VC1_005101_005651
# 551
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 526.5009360313416 s
#
# Processing SESID SVH_C5_S143_P286_VC1_005751_006201
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 527.2643897533417 s
#
# Processing SESID SVH_C5_S144_P287_VC1_003201_003701
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 528.0523715019226 s
#
# Processing SESID SVH_C5_S145_P289_VC1_003201_003951
# 751
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 529.0514290332794 s
#
# Processing SESID SVH_C5_S145_P290_VC1_006701_007101
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 529.7755868434906 s
#
# Processing SESID SVH_C5_S146_P291_VC1_007801_008201
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 530.5007674694061 s
#
# Processing SESID SVH_C5_S151_P301_VC1_006501_007001
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 531.3025918006897 s
#
# Processing SESID SVH_C5_S151_P302_VC1_007001_007401
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 532.0134444236755 s
#
# Processing SESID SVH_C6_S166_P332_VC1_000002_002001
# 2000
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 534.2175941467285 s
#
# Processing SESID SVH_C6_S168_P335_VC1_000002_002001
# 2000
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 536.360472202301 s
#
# Processing SESID SVH_C6_S168_P336_VC1_000002_002001
# 2000
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 538.5497069358826 s
#
# Processing SESID SVH_C6_S169_P337_VC1_000002_000629
# 628
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 539.4941837787628 s
#
# Processing SESID SVH_C6_S169_P338_VC1_000002_000855
# 854
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 540.6321334838867 s
#
# Processing SESID SVH_C6_S171_P341_VC1_000501_001225
# 725
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 541.6554071903229 s
#
# Processing SESID SVH_C6_S178_P355_VC1_001319_002624
# 1306
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 543.186559677124 s
#
# Processing SESID SVH_C6_S180_P359_VC1_000977_001457
# 481
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 543.9464268684387 s
#
# Processing SESID SVH_C6_S182_P363_VC1_000002_000625
# 624
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 544.868204832077 s
#
# Processing SESID SVH_C6_S183_P365_VC1_000290_000969
# 680
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 545.8296024799347 s
#
# Processing SESID SVH_C6_S183_P366_VC1_000254_001057
# 804
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 546.8551943302155 s
#
# Processing SESID SVH_C6_S185_P369_VC1_001335_001476
# 142
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 547.3323974609375 s
#
# Processing SESID SVH_C6_S186_P371_VC1_000002_002547
# 2546
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 550.0132901668549 s
#
# Processing SESID SVH_C6_S187_P373_VC1_000002_000671
# 670
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 550.9432702064514 s
#
# Processing SESID SVH_C6_S187_P374_VC1_000002_000614
# 613
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 551.8205411434174 s
#
# Processing SESID SVL_C1_S001_P001_VC1_003857_004977
# 1121
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 553.2048149108887 s
#
# Processing SESID SVL_C1_S006_P012_VC1_007601_008701
# 1101
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 554.5989978313446 s
#
# Processing SESID SVL_C1_S008_P015_VC1_002201_003201
# 1001
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 555.8996167182922 s
#
# Processing SESID SVL_C1_S014_P027_VC1_004045_006075
# 2031
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 558.099134683609 s
#
# Processing SESID SVL_C1_S014_P028_VC1_002595_004043
# 1449
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 559.7461578845978 s
#
# Processing SESID SVL_C1_S017_P034_VC1_001001_003801
# 2801
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 562.6059303283691 s
#
# Processing SESID SVL_C1_S018_P036_VC1_002718_004073
# 1356
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 564.1910774707794 s
#
# Processing SESID SVL_C1_S021_P041_VC1_002541_003447
# 907
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 565.3025951385498 s
#
# Processing SESID SVL_C1_S022_P044_VC1_003301_004095
# 795
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 566.4537672996521 s
#
# Processing SESID SVL_C1_S022_P044_VC1_007329_008693
# 1365
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 568.1319584846497 s
#
# Processing SESID SVL_C1_S023_P046_VC1_003001_004187
# 1187
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 569.5688576698303 s
#
# Processing SESID SVL_C1_S026_P052_VC1_001097_002123
# 1027
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 570.8918182849884 s
#
# Processing SESID SVL_C1_S027_P053_VC1_002061_003937
# 1877
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 572.9160485267639 s
#
# Processing SESID SVL_C1_S028_P056_VC1_007073_008192
# 1120
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 574.3917973041534 s
#
# Processing SESID SVL_C1_S192_P384_VC1_003696_005031
# 1336
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 575.9789242744446 s
#
# Processing SESID SVL_C2_S038_P075_VC1_000190_000785
# 596
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 576.8438944816589 s
#
# Processing SESID SVL_C2_S041_P081_VC1_003415_004258
# 844
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 577.9024550914764 s
#
# Processing SESID SVL_C2_S042_P083_VC1_001958_003364
# 1407
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 579.485969543457 s
#
# Processing SESID SVL_C2_S046_P092_VC1_002832_004061
# 1230
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 580.8938131332397 s
#
# Processing SESID SVL_C2_S047_P093_VC1_000538_001078
# 541
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 581.7164759635925 s
#
# Processing SESID SVL_C2_S047_P094_VC1_002101_002718
# 618
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 582.6129536628723 s
#
# Processing SESID SVL_C2_S048_P096_VC1_000837_001711
# 875
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 583.7491939067841 s
#
# Processing SESID SVL_C2_S049_P097_VC1_003160_004143
# 984
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 585.0088112354279 s
#
# Processing SESID SVL_C2_S050_P099_VC1_003700_004484
# 785
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 586.0683197975159 s
#
# Processing SESID SVL_C2_S050_P100_VC1_004223_004887
# 665
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 587.035285949707 s
#
# Processing SESID SVL_C2_S052_P103_VC1_003479_004267
# 789
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 588.0844922065735 s
#
# Processing SESID SVL_C2_S052_P104_VC1_004088_004607
# 520
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 588.8898067474365 s
#
# Processing SESID SVL_C2_S061_P121_VC1_003351_004387
# 1037
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 590.2113754749298 s
#
# Processing SESID SVL_C2_S062_P123_VC1_000489_001586
# 1098
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 591.6419761180878 s
#
# Processing SESID SVL_C2_S062_P124_VC1_001584_002535
# 952
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 592.8509821891785 s
#
# Processing SESID SVL_C2_S195_P389_VC1_002919_005001
# 2083
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 595.0075650215149 s
#
# Processing SESID SVL_C2_S195_P390_VC1_000301_002883
# 2583
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 597.6105782985687 s
#
# Processing SESID SVL_C2_S197_P393_VC1_000787_002868
# 2082
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 599.8472917079926 s
#
# Processing SESID SVL_C2_S199_P397_VC1_004085_004313
# 229
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 600.4759252071381 s
#
# Processing SESID SVL_C3_S064_P127_VC1_001291_001731
# 441
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 601.2202219963074 s
#
# Processing SESID SVL_C3_S066_P131_VC1_002151_002831
# 681
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 602.2093811035156 s
#
# Processing SESID SVL_C3_S069_P138_VC1_000381_001401
# 1021
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 603.4770274162292 s
#
# Processing SESID SVL_C3_S070_P140_VC1_002001_002531
# 531
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 604.2932252883911 s
#
# Processing SESID SVL_C3_S075_P150_VC1_005041_005637
# 597
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 605.1775124073029 s
#
# Processing SESID SVL_C3_S077_P153_VC1_007131_008161
# 1031
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 606.4860072135925 s
#
# Processing SESID SVL_C3_S078_P155_VC1_002241_002701
# 461
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 607.2509212493896 s
#
# Processing SESID SVL_C3_S078_P156_VC1_000921_001541
# 621
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 608.165194272995 s
#
# Processing SESID SVL_C3_S079_P157_VC1_003431_004061
# 631
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 609.0841422080994 s
#
# Processing SESID SVL_C3_S085_P169_VC1_003561_004931
# 1371
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 610.7770204544067 s
#
# Processing SESID SVL_C3_S086_P172_VC1_004181_004821
# 641
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 611.7056584358215 s
#
# Processing SESID SVL_C3_S090_P179_VC1_000481_001351
# 871
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 612.928325176239 s
#
# Processing SESID SVL_C3_S090_P180_VC1_001371_001981
# 611
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 613.8082473278046 s
#
# Processing SESID SVL_C3_S092_P183_VC1_000671_001681
# 1011
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 615.0797114372253 s
#
# Processing SESID SVL_C3_S093_P186_VC1_001351_002221
# 871
# 	csv frame rate: 50.00000000000001
# 	REsampling from 50.00000000000001 to 30.0
# Time taken: 616.2311720848083 s
#
# Processing SESID SVL_C4_S096_P191_VC1_008201_008700
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 617.0249054431915 s
#
# Processing SESID SVL_C4_S097_P193_VC1_002801_003300
# 500
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 617.8045680522919 s
#
# Processing SESID SVL_C4_S097_P194_VC1_006101_007000
# 900
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 618.9521813392639 s
#
# Processing SESID SVL_C4_S114_P228_VC1_005201_006600
# 1400
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 620.5133919715881 s
#
# Processing SESID SVL_C5_S134_P267_VC1_000451_000901
# 451
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 621.2600543498993 s
#
# Processing SESID SVL_C5_S138_P275_VC1_003101_003601
# 501
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 622.0528035163879 s
#
# Processing SESID SVL_C5_S143_P285_VC1_004051_004201
# 151
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 622.5349991321564 s
#
# Processing SESID SVL_C5_S143_P285_VC1_006701_006951
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 623.0975270271301 s
#
# Processing SESID SVL_C5_S143_P286_VC1_007001_007251
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 623.7240810394287 s
#
# Processing SESID SVL_C5_S143_P286_VC1_007251_007801
# 551
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 624.5684432983398 s
#
# Processing SESID SVL_C5_S145_P289_VC1_002851_003201
# 351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 625.2222535610199 s
#
# Processing SESID SVL_C5_S146_P292_VC1_005401_005601
# 201
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 625.7395269870758 s
#
# Processing SESID SVL_C5_S156_P312_VC1_000601_000851
# 251
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 626.3147628307343 s
#
# Processing SESID SVL_C5_S159_P318_VC1_000851_001401
# 551
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 627.1699900627136 s
#
# Processing SESID SVL_C5_S159_P318_VC1_002001_002601
# 601
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 628.0368602275848 s
#
# Processing SESID SVL_C5_S161_P321_VC1_002851_003201
# 351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 628.697735786438 s
#
# Processing SESID SVL_C5_S161_P321_VC1_007901_008251
# 351
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 629.3538720607758 s
#
# Processing SESID SVL_C5_S163_P325_VC1_001701_001851
# 151
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 629.8344955444336 s
#
# Processing SESID SVL_C5_S163_P325_VC1_003051_003451
# 401
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 630.5535969734192 s
#
# Processing SESID SVL_C6_S164_P328_VC1_006565_008499
# 1935
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 632.6663272380829 s
#
# Processing SESID SVL_C6_S166_P331_VC1_005137_006376
# 1240
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 634.1810727119446 s
#
# Processing SESID SVL_C6_S170_P339_VC1_000002_000778
# 777
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 635.1897926330566 s
#
# Processing SESID SVL_C6_S175_P349_VC1_000002_000865
# 864
# 	csv frame rate: 49.99999999999999
# 	REsampling from 49.99999999999999 to 30.0
# Time taken: 636.2702240943909 s
#
# Processing SESID SVL_C6_S176_P352_VC1_000002_000748
# 747
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 637.2081837654114 s
#
# Processing SESID SVL_C6_S177_P354_VC1_005501_007501
# 2001
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 639.2623658180237 s
#
# Processing SESID SVL_C6_S181_P361_VC1_003677_004747
# 1071
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 640.5586082935333 s
#
# Processing SESID SVL_C6_S181_P362_VC1_007841_008501
# 661
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 641.4650464057922 s
#
# Processing SESID SVL_C6_S188_P376_VC1_004038_004619
# 582
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 642.3367795944214 s
#
# Processing SESID SVL_C6_S189_P377_VC1_000002_000540
# 539
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 643.1533255577087 s
#
# Processing SESID SVL_C6_S189_P378_VC1_000227_001651
# 1425
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 644.7734000682831 s
#
# Processing SESID SVL_C6_S190_P379_VC1_000002_001069
# 1068
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 646.1187996864319 s
#
# Processing SESID SVL_C6_S190_P380_VC1_000002_001266
# 1265
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 647.6138007640839 s
#
# Processing SESID SVL_C6_S191_P381_VC1_000002_002059
# 2058
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 649.7880098819733 s
#
# Processing SESID SVL_C6_S191_P382_VC1_000002_001021
# 1020
# 	csv frame rate: 50.0
# 	REsampling from 50.0 to 30.0
# Time taken: 651.0645055770874 s
#
#
# Generated 538 annotated feature files.
